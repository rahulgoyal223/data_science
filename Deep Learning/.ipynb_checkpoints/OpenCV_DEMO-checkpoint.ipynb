# %% [markdown]
# ![image.png](attachment:image.png)
#
# ##### Learning Objectives (Open CV)
#
# - Learn about Open CV library
# - What is an Image and how to manipulate images
# - Some key functionalities avaialable within the library
# - Look at some real world applications using Image processing algorithms such as Edge detection contour detection etc.

# %%
# !pip install opencv-python

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import os

cv2.__version__
# Out:
# '4.5.1'

# %%
# gray scale images
img = cv2.imread("demo/sachin_gray_scale.jpg",cv2.IMREAD_GRAYSCALE)
img.shape
# Out:
# (206, 160)

# %%
img
# Out:
# array([[119, 119, 119, ..., 118, 117, 117],
#        [118, 118, 118, ..., 117, 117, 117],
#        [118, 118, 118, ..., 117, 117, 117],
#        ...,
#        [ 90,  88,  94, ..., 125, 125, 124],
#        [ 89,  89,  93, ..., 126, 126, 125],
#        [ 91,  89,  90, ..., 126, 127, 126]], dtype=uint8)

# %%
plt.imshow(img,cmap="gray")

# %%
# write array to excel file
temp = pd.DataFrame(img)
temp.to_excel("demo/Sachin_Image_excel.xlsx",index=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Reading a color image
img = cv2.imread("demo/sachin_color.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (206, 160, 3)

# %%
# view this image
plt.imshow(img)

# %%
plt.imshow(img[50:170,40:120,:])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(np.max(img))
print(np.min(img))
# Out:
# 255
# 0

# %%
### HSV color format
red1 = cv2.imread("DEMO/sample.png")
red1_hsv = cv2.cvtColor(red1,cv2.COLOR_BGR2HSV)
plt.imshow(red1_hsv,)

# %% [markdown]
# HSL (hue, saturation, lightness) and HSV (hue, saturation, value, also known as HSB or hue, saturation, brightness) are alternative representations of the RGB color model
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Image Histograms
#
# ![image.png](attachment:image.png)

# %%
# image historgrams
img_low_contrast = cv2.imread("demo/sachin_color.jpg",cv2.IMREAD_GRAYSCALE)
img_hist = cv2.calcHist(img_low_contrast,[0],None,[16],[0,255])

# %%
plt.plot(img_hist)

# %%
img_contrast_corrected = cv2.equalizeHist(img_low_contrast)
img_hist_corrected = cv2.calcHist(img_contrast_corrected,[0],None,[16],[0,255])
plt.plot(img_hist_corrected)

# %%
cv2.imwrite("demo/chk.jpg",img_contrast_corrected)
# Out:
# True

# %% [markdown]
# ### Reading Video

# %%
# Open a sample video available in sample-videos
vcap = cv2.VideoCapture('demo/sample_video.mp4')
count = 0

# %%
# frames per second
vcap.get(cv2.CAP_PROP_FPS)
# Out:
# 25.0

# %%
length = int(vcap.get(cv2.CAP_PROP_FRAME_COUNT))
print( length )
# Out:
# 2053

# %%
ret, frame = vcap.read()

# %%
plt.imshow(frame)

# %%
# read every nth frame
count=0
frame_num = []
while vcap.isOpened():
    ret, frame = vcap.read()
    if ret:
        frame_count = "frame_" + str(count) + ".jpg"
        cv2.imwrite(os.path.join('interim_results/frames', frame_count), frame)
        frame_num.append(frame_count)
        count += 60
        vcap.set(1, count)
    else:
        vcap.release()
        break

# %%
all_imgs = [cv2.cvtColor(cv2.imread(os.path.join("interim_results/frames",x)), cv2.COLOR_BGR2GRAY)
            for x in frame_num]

# %%
len(all_imgs)
# Out:
# 35

# %%
all_imgs[0].shape
# Out:
# (720, 1280)

# %%
plt.imshow(all_imgs[0],cmap='gray')

# %%
plt.imshow(all_imgs[0][0:350,700:1280],cmap='gray')

# %%
plt.imshow(all_imgs[0][0:50,400:700],cmap='gray')

# %%
for i in range(len(all_imgs)):
    all_imgs[i][0:350,700:1280] = 0
    all_imgs[i][0:70,250:700] = 0

# %%
plt.imshow(all_imgs[0],cmap='gray')

# %%
diff = cv2.subtract(all_imgs[0],all_imgs[1])

# %%
plt.imshow(diff,cmap='gray')

# %%
sample_sign = cv2.imread("demo/sample_sign.jpg")
sample_sign = cv2.cvtColor(sample_sign,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(sample_sign,cmap="gray")

# %%
kernel = np.ones((5,5),np.uint8)
sign_dilated = cv2.erode(sample_sign,kernel,30)
plt.imshow(sign_dilated,cmap="gray")

# %% [markdown]
# #### Morphological Operations
# - In short: A set of operations that process images based on shapes. Morphological operations apply a structuring element to an input image and generate an output image.
# - The most basic morphological operations are: Erosion and Dilation.
# - They have a wide array of uses, i.e. :
# 1. Removing noise
# 2. Isolation of individual elements and joining disparate elements in an image.
# 3. Finding of intensity bumps or holes in an image

# %% [markdown]
# ![image.png](attachment:image.png)`

# %%
diff_from_ref = []
for i in range(1,len(all_imgs)):
    
    diff = all_imgs[i-1] - all_imgs[i]
    kernel = np.ones((10,10),np.uint8)
    diff_dilated = cv2.erode(diff,kernel,100)
    diff_from_ref.append(np.sum(diff_dilated > 0)/(diff.shape[0]*diff.shape[1]))

# %%
res = pd.DataFrame({"frame":frame_num[1:],"diff":diff_from_ref})
res.sort_values(by="diff",ascending=False)
# Out:
#              frame      diff
# 33  frame_2040.jpg  0.045095
# 32  frame_1980.jpg  0.014166
# 11   frame_720.jpg  0.011993
# 12   frame_780.jpg  0.009106
# 13   frame_840.jpg  0.006308
# 14   frame_900.jpg  0.004225
# 21  frame_1320.jpg  0.003984
# 25  frame_1560.jpg  0.003763
# 16  frame_1020.jpg  0.003737
# 27  frame_1680.jpg  0.003525
# 6    frame_420.jpg  0.003490
# 17  frame_1080.jpg  0.003477
# 8    frame_540.jpg  0.003167
# 29  frame_1800.jpg  0.003162
# 31  frame_1920.jpg  0.002728
# 10   frame_660.jpg  0.002464
# 19  frame_1200.jpg  0.002408
# 23  frame_1440.jpg  0.002371
# 2    frame_180.jpg  0.002228
# 4    frame_300.jpg  0.002014
# 1    frame_120.jpg  0.001962
# 9    frame_600.jpg  0.001329
# 18  frame_1140.jpg  0.001286
# 30  frame_1860.jpg  0.001054
# 3    frame_240.jpg  0.001044
# 5    frame_360.jpg  0.000878
# 15   frame_960.jpg  0.000871
# 22  frame_1380.jpg  0.000720
# 7    frame_480.jpg  0.000706
# 28  frame_1740.jpg  0.000656
# 24  frame_1500.jpg  0.000545
# 20  frame_1260.jpg  0.000480
# 26  frame_1620.jpg  0.000378
# 0     frame_60.jpg  0.000139

# %%
[idx for idx,val in enumerate(frame_num) if val == "frame_2040.jpg"]
# Out:
# [34]

# %%
plt.imshow(all_imgs[34],cmap="gray")

# %%
img_id = 34
diff = cv2.subtract(all_imgs[img_id-1],  all_imgs[img_id])
kernel = np.ones((5,5),np.uint8)
diff_dilated = cv2.erode(diff,kernel,12)
plt.imshow(diff_dilated,cmap="gray")

# %%
sachin_img = cv2.imread("demo/sachin_gray_scale.jpg",cv2.IMREAD_GRAYSCALE)
sachin_img = cv2.GaussianBlur(sachin_img,(5,5),1)
#sachin_img = cv2.blur(sachin_img,(5,5))
sachin_img_edge = cv2.Canny(sachin_img, 10,200)

# %%
sachin_img_edge = 255 - sachin_img_edge

# %%
plt.imshow(sachin_img_edge,cmap="gray")

# %% [markdown]
# ### Canny Edge Detection
#
# - Here we find the edge by taking the gradient of the image, We perform a 2-D spatial mesurement on an image
# - Usually pair of 3 X 3 convolution mask one estimating the gradient in the x-direction and the other estimating the gradient in the y-direction.

# %% [markdown]
# ![image.png](attachment:image.png)
# https://towardsdatascience.com/canny-edge-detection-step-by-step-in-python-computer-vision-b49c3a2d8123

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Contours
#
# ###### Contours can be explained simply as a curve joining all the continuous points (along the boundary), having same color or intensity. The contours are a useful tool for shape analysis and object detection and recognition.
#
# - For better accuracy, use binary images. So before finding contours, apply threshold or canny edge detection.
# - In OpenCV, finding contours is like finding white object from black background. So remember, object to be found should be white and background should be black.

# %%
img = cv2.imread("demo/car_num_plate.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
gray_img = cv2.GaussianBlur(gray_img,(3,3),0)

# %%
plt.imshow(img_rgb)

# %%
plt.imshow(gray_img,cmap='gray')

# %%
## edge detection
edged = cv2.Canny(gray_img, 10,200)

# %%
cv2.imwrite("demo/chk.jpg",edged)
# Out:
# True

# %%
edged = 255-edged
plt.imshow(edged,cmap="gray")

# %%
edged = cv2.Canny(gray_img, 10, 200) 
contours, _ = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# %%
len(contours)
# Out:
# 128

# %%
contours = sorted(contours, key = cv2.contourArea, reverse = True)[:10]

# %% [markdown]
# #### Contour Approximation
#
# It approximates a contour shape to another shape with less number of vertices depending upon the precision we specify. It is an implementation of Douglas-Peucker algorithm.
#
# ![image.png](attachment:image.png)
#
# https://docs.opencv.org/master/dd/d49/tutorial_py_contour_features.html

# %%
rect_contours = []
for c in contours:
    
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.01 * peri, True)
 
    if len(approx) == 4:
        rect_contours.append(approx)
        break

# %%
len(rect_contours)
# Out:
# 1

# %%
rect_contours
# Out:
# [array([[[164, 243]],
#
#         [[326, 243]],
#
#         [[329, 281]],
#
#         [[167, 282]]], dtype=int32)]

# %%
plt.imshow(cv2.drawContours(img, [rect_contours[0]], -1, (0, 0, 255), 3))

# %%
mask = np.zeros(gray_img.shape,np.uint8)
mask = cv2.drawContours(mask,[rect_contours[0]],contourIdx=0, color=255,thickness=-1)

# %%
plt.imshow(mask,cmap="gray")

# %%
num_plate = cv2.bitwise_and(img,img,mask=mask)
plt.imshow(num_plate,cmap="gray")

# %%
(x, y) = np.where(mask == 255)
(top_x, top_y) = (np.min(x), np.min(y))
(bottom_x, bottom_y) = (np.max(x), np.max(y))
cropped_num_plate = num_plate[top_x:bottom_x+1, top_y:bottom_y+1]

# %%
plt.imshow(cropped_num_plate)
