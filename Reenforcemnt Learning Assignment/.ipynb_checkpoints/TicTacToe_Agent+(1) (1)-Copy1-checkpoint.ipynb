# %% [markdown]
# ## Tic-Tac-Toe Agent
# ​
# In this notebook, you will learn to build an RL agent (using Q-learning) that learns to play Numerical Tic-Tac-Toe with odd numbers. The environment is playing randomly with the agent, i.e. its strategy is to put an even number randomly in an empty cell. The following is the layout of the notebook:
#         - Defining epsilon-greedy strategy
#         - Tracking state-action pairs for convergence
#         - Define hyperparameters for the Q-learning algorithm
#         - Generating episode and applying Q-update equation
#         - Checking convergence in Q-values

# %% [markdown]
# #### Importing libraries
# Write the code to import Tic-Tac-Toe class from the environment file

# %%
# from <TC_Env> import <TicTacToe> - import your class from environment file
import collections
import numpy as np
import random
import pickle
import time
from matplotlib import pyplot as plt
from TCGame_Env1 import TicTacToe

# %%
# Function to convert state array into a string to store it as keys in the dictionary
# states in Q-dictionary will be of form: x-4-5-3-8-x-x-x-x
#   x | 4 | 5
#   ----------
#   3 | 8 | x
#   ----------
#   x | x | x

def Q_state(state):

    return ('-'.join(str(e) for e in state)).replace('nan','x')

# %%
# Defining a function which will return valid (all possible actions) actions corresponding to a state
# Important to avoid errors during deployment.

def valid_actions(state):

    valid_Actions = []
    
    valid_Actions = [i for i in env.action_space(state)[0]] ###### -------please call your environment as env
    return valid_Actions

# %%
# Defining a function which will add new Q-values to the Q-dictionary. 
def add_to_dict(state):
    state1 = Q_state(state)
    
    valid_act = valid_actions(state)
    if state1 not in Q_dict.keys():
        for action in valid_act:
            Q_dict[state1][action]=0

# %% [markdown]
# #### Epsilon-greedy strategy - Write your code here
#
# (you can build your epsilon-decay function similar to the one given at the end of the notebook)

# %%
# Defining epsilon-greedy policy. You can choose any function epsilon-decay strategy
def epsilon_greedy(state, time):
    epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate*time)
    # print(epsilon)
    z = np.random.random()
        
    if z > epsilon:
        state1 = Q_state(state)
        action = max(Q_dict[state1],key=Q_dict[state1].get)   #Exploitation: this gets the action corresponding to max q-value of current state
    else:
        possible_action = [i for i in env.action_space(state)[0]]        
        action = possible_action[np.random.choice(range(len(possible_action)))]    #Exploration: randomly choosing and action
    
    return action

# %% [markdown]
# #### Tracking the state-action pairs for checking convergence - write your code here

# %%
# Initialise Q_dictionary as 'Q_dict' and States_tracked as 'States_track' (for convergence)
Q_dict = collections.defaultdict(dict)
States_track =collections.defaultdict(dict)

# %%
# Initialise states to be tracked
def initialise_tracking_states():
    Sample_Qvalues = [('x-x-x-x-x-x-x-x-x',(6,5)),('x-x-x-x-x-x-x-x-x',(1,9)),
                       ('x-3-x-x-1-x-x-x-x',(7,5)),('x-5-x-x-x-x-5-7-x',(8,2))]    #select some 4 Q-values
    for q_values in Sample_Qvalues:
        state = q_values[0]
        action = q_values[1]
        States_track[state][action] = []

# %%
#Defining a function to save the Q-dictionary as a pickle file

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
def save_tracking_states():
    for state in States_track.keys():
        for action in States_track[state].keys():
            if state in Q_dict and action in Q_dict[state]:
                States_track[state][action].append(Q_dict[state][action])

# %%
initialise_tracking_states()

# %% [markdown]
# #### Define hyperparameters  ---write your code here

# %%
#Defining parameters for the training

EPISODES = 10000000
LR = 0.01                   # learning rate
GAMMA = 0.9                # discount factor

max_epsilon = 1.0
min_epsilon = 0.001
decay_rate = 0.001        # epsilon decay rate
threshold = 200       # no of episodes after which states_tracked wwill be saved
print_threshold = 50000   # no of episodes after which Q dictionary/table will be saved

# %% [markdown]
# ### Q-update loop ---write your code here

# %%
start_time = time.time()
for episode in range(EPISODES):
    env = TicTacToe()  # call the environment
    curr_state = env.state
    isTerminal = False
    add_to_dict(curr_state)  # adding the current state to dictionary

    while not isTerminal:
        curr_state1 = Q_state(curr_state)
        curr_action = epsilon_greedy(curr_state, episode)  # applying epislon method
        reward, next_state, isTerminal = env.step(curr_state, curr_action)  # getting rewar
        next_state_temp = Q_state(next_state)
        add_to_dict(next_state)
        
        # Updating rules
        if not isTerminal:
            max_next = max(Q_dict[next_state_temp], key=Q_dict[next_state_temp].get)
            Q_dict[curr_state1][curr_action] += LR * ((reward + (GAMMA * (Q_dict[next_state_temp][max_next])))
                                                          - Q_dict[curr_state1][curr_action])
        else:
            Q_dict[curr_state1][curr_action] += LR * ((reward - Q_dict[curr_state1][curr_action]))
            if reward = 10
            
        # navigating to next state
        curr_state = next_state

    # states tracking   
    if ((episode + 1) % threshold) == 0:
        save_tracking_states()
        #save_obj(States_track, 'States_tracking') 
    
    #save_obj(Q_dict, 'Policy_Q_dict')
    if ((episode + 1) % print_threshold) == 0:  # every 300th episodes, the Q-dict will be saved
        
        print("Episode {} is completed".format(episode))

elapsed_time = time.time() - start_time
save_obj(States_track, 'States_tracking')
save_obj(Q_dict, 'Policy_Q_dict')
print("Time", elapsed_time)
# Out:
# Episode 49999 is completed
# Episode 99999 is completed
# Episode 149999 is completed
# Episode 199999 is completed
# Episode 249999 is completed
# Episode 299999 is completed
# Episode 349999 is completed
# Episode 399999 is completed
# Episode 449999 is completed
# Episode 499999 is completed
# Episode 549999 is completed
# Episode 599999 is completed
# Episode 649999 is completed
# Episode 699999 is completed
# Episode 749999 is completed
# Episode 799999 is completed
# Episode 849999 is completed
# Episode 899999 is completed
# Episode 949999 is completed
# Episode 999999 is completed
# Episode 1049999 is completed
# Episode 1099999 is completed
# Episode 1149999 is completed
# Episode 1199999 is completed
# Episode 1249999 is completed
# Episode 1299999 is completed
# Episode 1349999 is completed
# Episode 1399999 is completed
# Episode 1449999 is completed
# Episode 1499999 is completed
# Episode 1549999 is completed
# Episode 1599999 is completed
# Episode 1649999 is completed
# Episode 1699999 is completed
# Episode 1749999 is completed
# Episode 1799999 is completed
# Episode 1849999 is completed
# Episode 1899999 is completed
# Episode 1949999 is completed
# Episode 1999999 is completed
# Episode 2049999 is completed
# Episode 2099999 is completed
# Episode 2149999 is completed
# Episode 2199999 is completed
# Episode 2249999 is completed
# Episode 2299999 is completed
# Episode 2349999 is completed
# Episode 2399999 is completed
# Episode 2449999 is completed
# Episode 2499999 is completed
# Episode 2549999 is completed
# Episode 2599999 is completed
# Episode 2649999 is completed
# Episode 2699999 is completed
# Episode 2749999 is completed
# Episode 2799999 is completed
# Episode 2849999 is completed
# Episode 2899999 is completed
# Episode 2949999 is completed
# Episode 2999999 is completed
# Episode 3049999 is completed
# Episode 3099999 is completed
# Episode 3149999 is completed
# Episode 3199999 is completed
# Episode 3249999 is completed
# Episode 3299999 is completed
# Episode 3349999 is completed
# Episode 3399999 is completed
# Episode 3449999 is completed
# Episode 3499999 is completed
# Episode 3549999 is completed
# Episode 3599999 is completed
# Episode 3649999 is completed
# Episode 3699999 is completed
# Episode 3749999 is completed
# Episode 3799999 is completed
# Episode 3849999 is completed
# Episode 3899999 is completed
# Episode 3949999 is completed
# Episode 3999999 is completed
# Episode 4049999 is completed
# Episode 4099999 is completed
# Episode 4149999 is completed
# Episode 4199999 is completed
# Episode 4249999 is completed
# Episode 4299999 is completed
# Episode 4349999 is completed
# Episode 4399999 is completed
# Episode 4449999 is completed
# Episode 4499999 is completed
# Episode 4549999 is completed
# Episode 4599999 is completed
# Episode 4649999 is completed
# Episode 4699999 is completed
# Episode 4749999 is completed
# Episode 4799999 is completed
# Episode 4849999 is completed
# Episode 4899999 is completed
# Episode 4949999 is completed
# Episode 4999999 is completed
# Episode 5049999 is completed
# Episode 5099999 is completed
# Episode 5149999 is completed
# Episode 5199999 is completed
# Episode 5249999 is completed
# Episode 5299999 is completed
# Episode 5349999 is completed
# Episode 5399999 is completed
# Episode 5449999 is completed
# Episode 5499999 is completed
# Episode 5549999 is completed
# Episode 5599999 is completed
# Episode 5649999 is completed
# Episode 5699999 is completed
# Episode 5749999 is completed
# Episode 5799999 is completed
# Episode 5849999 is completed
# Episode 5899999 is completed
# Episode 5949999 is completed
# Episode 5999999 is completed
# Episode 6049999 is completed
# Episode 6099999 is completed
# Episode 6149999 is completed
# Episode 6199999 is completed
# Episode 6249999 is completed
# Episode 6299999 is completed
# Episode 6349999 is completed
# Episode 6399999 is completed
# Episode 6449999 is completed
# Episode 6499999 is completed
# Episode 6549999 is completed
# Episode 6599999 is completed
# Episode 6649999 is completed
# Episode 6699999 is completed
# Episode 6749999 is completed
# Episode 6799999 is completed
# Episode 6849999 is completed
# Episode 6899999 is completed
# Episode 6949999 is completed
# Episode 6999999 is completed
# Episode 7049999 is completed
# Episode 7099999 is completed
# Episode 7149999 is completed
# Episode 7199999 is completed
# Episode 7249999 is completed
# Episode 7299999 is completed
# Episode 7349999 is completed
# Episode 7399999 is completed
# Episode 7449999 is completed
# Episode 7499999 is completed
# Episode 7549999 is completed
# Episode 7599999 is completed
# Episode 7649999 is completed
# Episode 7699999 is completed
# Episode 7749999 is completed
# Episode 7799999 is completed
# Episode 7849999 is completed
# Episode 7899999 is completed
# Episode 7949999 is completed
# Episode 7999999 is completed
# Episode 8049999 is completed
# Episode 8099999 is completed
# Episode 8149999 is completed
# Episode 8199999 is completed
# Episode 8249999 is completed
# Episode 8299999 is completed
# Episode 8349999 is completed
# Episode 8399999 is completed
# Episode 8449999 is completed
# Episode 8499999 is completed
# Episode 8549999 is completed
# Episode 8599999 is completed
# Episode 8649999 is completed
# Episode 8699999 is completed
# Episode 8749999 is completed
# Episode 8799999 is completed
# Episode 8849999 is completed
# Episode 8899999 is completed
# Episode 8949999 is completed
# Episode 8999999 is completed
# Episode 9049999 is completed
# Episode 9099999 is completed
# Episode 9149999 is completed
# Episode 9199999 is completed
# Episode 9249999 is completed
# Episode 9299999 is completed
# Episode 9349999 is completed
# Episode 9399999 is completed
# Episode 9449999 is completed
# Episode 9499999 is completed
# Episode 9549999 is completed
# Episode 9599999 is completed
# Episode 9649999 is completed
# Episode 9699999 is completed
# Episode 9749999 is completed
# Episode 9799999 is completed
# Episode 9849999 is completed
# Episode 9899999 is completed
# Episode 9949999 is completed
# Episode 9999999 is completed
# Time 4465.048186302185

# %% [markdown]
# #### Check the Q-dictionary

# %%
Q_dict
# Out:
# defaultdict(dict,
#             {'x-x-x-x-x-x-x-x-x': {(0, 1): -1.2463412707927264,
#               (0, 3): -1.240170198284791,
#               (0, 5): -1.2457574439790156,
#               (0, 7): -1.2408188171940049,
#               (0, 9): -1.2442852401307551,
#               (1, 1): -1.2448000971335589,
#               (1, 3): -1.242086204573993,
#               (1, 5): -1.2379627427501163,
#               (1, 7): -1.245415356384188,
#               (1, 9): -1.2382300952868142,
#               (2, 1): -1.2424156433953302,
#               (2, 3): -1.2444265066802092,
#               (2, 5): -1.2435556722488343,
#               (2, 7): -1.244095207574168,
#               (2, 9): -1.2412833245386259,
#               (3, 1): -1.2282470444754534,
#               (3, 3): -1.2407055735487014,
#               (3, 5): -1.1913677178277682,
#               (3, 7): -1.2389663271379192,
#               (3, 9): -1.2454780106456973,
#               (4, 1): -1.2442086008437254,
#               (4, 3): -1.2376636855030811,
#               (4, 5): -1.2451104689414534,
#               (4, 7): -1.2445946968292523,
#               (4, 9): -1.2392027972137893,
#               (5, 1): -1.2453503083790978,
#               (5, 3): -1.2462829380887628,
#               (5, 5): -1.239855935466476,
#               (5, 7): -1.2393888870660306,
#               (5, 9): -1.2457448563340752,
#               (6, 1): -1.2418787530110658,
#               (6, 3): -1.2429076584494827,
#               (6, 5): -1.2431172585708834,
#               (6, 7): -1.2423508760605846,
#               (6, 9): 5.134279505398943,
#               (7, 1): -1.2446613901107233,
#               (7, 3): -1.2444058321840936,
#               (7, 5): -1.244623433926972,
#               (7, 7): -1.239949516820584,
#               (7, 9): -1.2406309895359529,
#               (8, 1): -1.2422890553627013,
#               (8, 3): -1.2419062320867666,
#               (8, 5): -1.2460115878622995,
#               (8, 7): -1.2433553588853095,
#               (8, 9): -1.2431677402154884},
#              'x-x-9-x-x-x-x-8-x': {(0, 1): -0.24334959458845565,
#               (0, 3): -0.2434445100859194,
#               (0, 5): -0.2427778937356063,
#               (0, 7): -0.24197356504462755,
#               (1, 1): -0.30641667332239025,
#               (1, 3): -0.2452807127963673,
#               (1, 5): -0.2450499583428145,
#               (1, 7): -0.2452807127963673,
#               (3, 1): -0.24341738565721668,
#               (3, 3): -0.2422185554823908,
#               (3, 5): -0.24622336472793865,
#               (3, 7): -0.24532962643073614,
#               (4, 1): -0.2554643055720799,
#               (4, 3): -0.27687829801481123,
#               (4, 5): -0.2444631306198195,
#               (4, 7): -0.2452807127963673,
#               (5, 1): -0.2452807127963673,
#               (5, 3): -0.2426694626514573,
#               (5, 5): -0.24262553279636728,
#               (5, 7): -0.24356028534245724,
#               (6, 1): -0.24930993295637907,
#               (6, 3): -0.3043012097295345,
#               (6, 5): -0.24179002006216313,
#               (6, 7): -0.2443807127963673,
#               (8, 1): -0.31993661565591675,
#               (8, 3): -0.24288248282833633,
#               (8, 5): -0.24893761469492118,
#               (8, 7): -0.2452807127963673},
#              'x-x-9-x-x-x-2-8-5': {(0, 1): 0,
#               (0, 3): 0,
#               (0, 7): 0,
#               (1, 1): 0,
#               (1, 3): 0,
#               (1, 7): 0,
#               (3, 1): 0,
#               (3, 3): 0,
#               (3, 7): 0,
#               (4, 1): 0,
#               (4, 3): 0,
#               (4, 7): 0,
#               (5, 1): 0,
#               (5, 3): 0,
#               (5, 7): 0},
#              'x-1-x-x-x-x-x-6-x': {(0, 3): -0.36164523698307594,
#               (0, 5): -0.32825032615151806,
#               (0, 7): -0.33102824143031945,
#               (0, 9): -0.3965091972913203,
#               (2, 3): -0.3603020624027692,
#               (2, 5): -0.4071857119843237,
#               (2, 7): -0.328692793072957,
#               (2, 9): -0.3287757434986015,
#               (3, 3): -0.36937213177874145,
#               (3, 5): -0.3279341441989115,
#               (3, 7): -0.32667968289334715,
#               (3, 9): -0.33263101483292157,
#               (4, 3): -0.33102824143031945,
#               (4, 5): -0.33102824143031945,
#               (4, 7): -0.33102824143031945,
#               (4, 9): -0.33102824143031945,
#               (5, 3): -0.32945910506694237,
#               (5, 5): -0.3794467727277076,
#               (5, 7): -0.3291516879277022,
#               (5, 9): -0.32830789950287687,
#               (6, 3): -0.3300139262424573,
#               (6, 5): -0.407416867359576,
#               (6, 7): -0.33438371661607313,
#               (6, 9): -0.3290995520070732,
#               (8, 3): -0.33102824143031945,
#               (8, 5): -0.3722853214573984,
#               (8, 7): -0.4217459111070731,
#               (8, 9): -0.3326791278364798},
#              '8-1-x-x-x-x-5-6-x': {(2, 3): -0.01,
#               (2, 7): -0.01,
#               (2, 9): -0.01,
#               (3, 3): -0.01,
#               (3, 7): -0.01,
#               (3, 9): 0,
#               (4, 3): 0,
#               (4, 7): 0,
#               (4, 9): 0,
#               (5, 3): 0,
#               (5, 7): 0,
#               (5, 9): 0,
#               (8, 3): 0,
#               (8, 7): 0,
#               (8, 9): 0},
#              '8-1-9-4-x-x-5-6-x': {(4, 3): -0.01,
#               (4, 7): 0,
#               (5, 3): 0,
#               (5, 7): 0,
#               (8, 3): 0,
#               (8, 7): 0},
#              '8-1-9-4-3-x-5-6-2': {(5, 7): 0.0},
#              '8-x-x-x-7-x-x-x-x': {(1, 1): -0.2470568066160731,
#               (1, 3): -0.2364659700301,
#               (1, 5): -0.2777087682397964,
#               (1, 9): -0.23926249316041923,
#               (2, 1): -0.3080792727616416,
#               (2, 3): -0.2399947755391,
#               (2, 5): -0.23675122890512434,
#               (2, 9): -0.23765728565289626,
#               (3, 1): -0.28000132795570304,
#               (3, 3): -0.32156288212622924,
#               (3, 5): -0.28596114359751684,
#               (3, 9): -0.24111478882776477,
#               (5, 1): -0.23804834055269888,
#               (5, 3): -0.23520154779907923,
#               (5, 5): -0.2411778058489227,
#               (5, 9): -0.24050212214915856,
#               (6, 1): -0.2402299994436043,
#               (6, 3): -0.23756358546892142,
#               (6, 5): -0.2370025585519161,
#               (6, 9): -0.2400376175822971,
#               (7, 1): -0.24185024040910635,
#               (7, 3): -0.2366883367809437,
#               (7, 5): -0.23627124108435082,
#               (7, 9): -0.23858652781310205,
#               (8, 1): -0.23620033956543085,
#               (8, 3): -0.23865689587751504,
#               (8, 5): -0.2402903593099661,
#               (8, 9): -0.2405701825033201},
#              '8-x-x-x-7-4-9-x-x': {(1, 1): -0.01,
#               (1, 3): -0.01,
#               (1, 5): -0.01,
#               (2, 1): -0.01,
#               (2, 3): -0.01,
#               (2, 5): -0.01,
#               (3, 1): -0.01,
#               (3, 3): -0.01,
#               (3, 5): -0.018788080903201432,
#               (7, 1): 0,
#               (7, 3): 0,
#               (7, 5): 0,
#               (8, 1): 0,
#               (8, 3): 0,
#               (8, 5): -0.01},
#              '8-2-x-x-7-4-9-x-5': {(2, 1): 0,
#               (2, 3): 0,
#               (3, 1): 0,
#               (3, 3): -0.1,
#               (7, 1): 0,
#               (7, 3): 0},
#              '8-2-x-3-7-4-9-6-5': {(2, 1): 0},
#              'x-x-x-x-2-9-x-x-x': {(0, 1): -0.34511664511585693,
#               (0, 3): -0.42901497151141244,
#               (0, 5): -0.34949831432048506,
#               (0, 7): -0.34597839866292607,
#               (1, 1): -0.3602805658911955,
#               (1, 3): -0.38658121034132364,
#               (1, 5): -0.3434713079799996,
#               (1, 7): -0.38949249465006125,
#               (2, 1): -0.4182873288277022,
#               (2, 3): -0.434283560295618,
#               (2, 5): -0.34251617888524727,
#               (2, 7): -0.3450441674760424,
#               (3, 1): -0.34631631496166876,
#               (3, 3): -0.3489952965817585,
#               (3, 5): -0.3443407794258561,
#               (3, 7): -0.3443407794258561,
#               (6, 1): -0.3464162915477673,
#               (6, 3): -0.3441112649113275,
#               (6, 5): -0.3466813034163591,
#               (6, 7): -0.35505762630282467,
#               (7, 1): -0.3428279056684036,
#               (7, 3): -0.4283218500098649,
#               (7, 5): -0.37222935480704405,
#               (7, 7): -0.34942496596244915,
#               (8, 1): -0.34279523854991245,
#               (8, 3): -0.4072837641948447,
#               (8, 5): -0.3979880971498826,
#               (8, 7): -0.4368387750148719},
#              '6-x-x-x-2-9-x-1-x': {(1, 3): -0.01,
#               (1, 5): -0.01,
#               (1, 7): -0.01,
#               (2, 3): -0.01,
#               (2, 5): -0.01,
#               (2, 7): -0.01,
#               (3, 3): -0.01,
#               (3, 5): -0.01,
#               (3, 7): 0,
#               (6, 3): 0,
#               (6, 5): 0,
#               (6, 7): 0,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 7): 0},
#              '6-7-x-8-2-9-x-1-x': {(2, 3): 0,
#               (2, 5): 0,
#               (6, 3): 0,
#               (6, 5): -0.01,
#               (8, 3): 0,
#               (8, 5): 0},
#              '6-7-x-8-2-9-5-1-4': {(2, 3): 0.0},
#              '2-x-x-x-x-9-x-x-x': {(1, 1): -0.23765728565289626,
#               (1, 3): -0.23765728565289626,
#               (1, 5): -0.23765728565289626,
#               (1, 7): -0.24135112595446584,
#               (2, 1): -0.23677519565289626,
#               (2, 3): -0.23679274924389626,
#               (2, 5): -0.23765728565289626,
#               (2, 7): -0.23675122890512434,
#               (3, 1): -0.2410361329571522,
#               (3, 3): -0.23914731982885937,
#               (3, 5): -0.23687958096557604,
#               (3, 7): -0.24129527242571586,
#               (4, 1): -0.23642699550120252,
#               (4, 3): -0.23550512646856234,
#               (4, 5): -0.23604090945238143,
#               (4, 7): -0.3178854366929271,
#               (6, 1): -0.23925023951496815,
#               (6, 3): -0.24020637578422033,
#               (6, 5): -0.23675122890512434,
#               (6, 7): -0.24617471661607312,
#               (7, 1): -0.2376628660436104,
#               (7, 3): -0.24043465359228552,
#               (7, 5): -0.23765728565289626,
#               (7, 7): -0.24050573954088292,
#               (8, 1): -0.23547823684272418,
#               (8, 3): -0.23802946295020075,
#               (8, 5): -0.23918272789563907,
#               (8, 7): -0.24619227020707313},
#              '2-x-x-x-3-9-x-4-x': {(1, 1): -0.01,
#               (1, 5): -0.01,
#               (1, 7): -0.01,
#               (2, 1): -0.01,
#               (2, 5): 0,
#               (2, 7): 0,
#               (3, 1): 0,
#               (3, 5): 0,
#               (3, 7): 0,
#               (6, 1): 0,
#               (6, 5): -0.01,
#               (6, 7): 0,
#               (8, 1): 0,
#               (8, 5): 0,
#               (8, 7): 0},
#              '2-x-x-6-3-9-5-4-x': {(1, 1): 0,
#               (1, 7): -0.01,
#               (2, 1): 0,
#               (2, 7): 0,
#               (8, 1): 0,
#               (8, 7): 0},
#              '2-7-8-6-3-9-5-4-x': {(8, 1): 0.0},
#              'x-x-x-x-x-5-x-x-2': {(0, 1): -0.3502996266117196,
#               (0, 3): -0.3568262758488591,
#               (0, 7): -0.2928393572563445,
#               (0, 9): -0.3551400849012819,
#               (1, 1): -0.29371262635634454,
#               (1, 3): -0.2936039261287823,
#               (1, 7): -0.2973817874279041,
#               (1, 9): -0.2972848791313611,
#               (2, 1): -0.2926956720712128,
#               (2, 3): -0.2925071355398416,
#               (2, 7): -0.2921414094914306,
#               (2, 9): -0.29442770324047896,
#               (3, 1): -0.378698398802475,
#               (3, 3): -0.2913168622276683,
#               (3, 7): -0.33211743794845117,
#               (3, 9): -0.2941728744660075,
#               (4, 1): -0.3404625755629521,
#               (4, 3): -0.2945947163563445,
#               (4, 7): -0.295790264984604,
#               (4, 9): -0.362509773392076,
#               (6, 1): -0.29258475757183283,
#               (6, 3): -0.2953238824944875,
#               (6, 7): -0.297212190447122,
#               (6, 9): -0.295421190447122,
#               (7, 1): -0.3478182693412675,
#               (7, 3): -0.29736888169129394,
#               (7, 7): -0.2958661965575181,
#               (7, 9): -0.3163952862587115},
#              'x-6-x-x-x-5-1-x-2': {(0, 3): -0.01,
#               (0, 7): -0.01,
#               (0, 9): -0.01,
#               (2, 3): -0.01,
#               (2, 7): -0.01,
#               (2, 9): 0,
#               (3, 3): 0,
#               (3, 7): 0,
#               (3, 9): 0,
#               (4, 3): 0,
#               (4, 7): 0,
#               (4, 9): 0,
#               (7, 3): 0,
#               (7, 7): -0.01,
#               (7, 9): 0},
#              'x-6-x-4-x-5-1-7-2': {(0, 3): 0,
#               (0, 9): 0,
#               (2, 3): 0,
#               (2, 9): 0,
#               (4, 3): 0,
#               (4, 9): -0.01},
#              '8-6-x-4-9-5-1-7-2': {(2, 3): 0.0},
#              'x-x-x-x-4-x-3-x-x': {(0, 1): -0.3745962964322662,
#               (0, 5): -0.3463688307082919,
#               (0, 7): -0.30794155197438094,
#               (0, 9): -0.3783852990029489,
#               (1, 1): -0.30357302735164576,
#               (1, 5): -0.3016663227837811,
#               (1, 7): -0.30432185919278104,
#               (1, 9): -0.3642342978655075,
#               (2, 1): -0.30582362894194015,
#               (2, 5): -0.30577153410651947,
#               (2, 7): -0.3056143035349198,
#               (2, 9): -0.3041921534291364,
#               (3, 1): -0.30011310423250614,
#               (3, 5): -0.37216435622096067,
#               (3, 7): -0.37725073297634765,
#               (3, 9): -0.3033894965048888,
#               (5, 1): -0.3495889950685068,
#               (5, 5): -0.3502633034163591,
#               (5, 7): -0.3007755000927811,
#               (5, 9): -0.30164876919278105,
#               (7, 1): -0.30522191342113303,
#               (7, 5): -0.305225663099366,
#               (7, 7): -0.3411883245744182,
#               (7, 9): -0.3511582861644133,
#               (8, 1): -0.3529313761644133,
#               (8, 5): -0.29889133564583115,
#               (8, 7): -0.30104469995793903,
#               (8, 9): -0.30211340509456064},
#              '7-6-x-x-4-x-3-x-x': {(2, 1): -0.01,
#               (2, 5): -0.01,
#               (2, 9): -0.01,
#               (3, 1): -0.01,
#               (3, 5): 0,
#               (3, 9): 0,
#               (5, 1): 0,
#               (5, 5): 0,
#               (5, 9): 0,
#               (7, 1): -0.01,
#               (7, 5): 0,
#               (7, 9): 0,
#               (8, 1): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '7-6-x-x-4-x-3-1-2': {(2, 5): -0.1,
#               (2, 9): -0.01,
#               (3, 5): 0,
#               (3, 9): 0,
#               (5, 5): 0,
#               (5, 9): 0},
#              '7-6-5-x-4-8-3-1-2': {(3, 9): 0},
#              'x-x-3-x-x-2-x-x-x': {(0, 1): -0.2299568541948447,
#               (0, 5): -0.2353195226478297,
#               (0, 7): -0.23456593825327848,
#               (0, 9): -0.235239305031161,
#               (1, 1): -0.23678401655289624,
#               (1, 5): -0.2358474385794114,
#               (1, 7): -0.22970117756051184,
#               (1, 9): -0.2299568541948447,
#               (3, 1): -0.2299568541948447,
#               (3, 5): -0.30432185919278104,
#               (3, 7): -0.2299568541948447,
#               (3, 9): -0.23683144507052475,
#               (4, 1): -0.2299568541948447,
#               (4, 5): -0.23327544235121436,
#               (4, 7): -0.23675122890512434,
#               (4, 9): -0.2299568541948447,
#               (6, 1): -0.2368514812240634,
#               (6, 5): -0.23676628565289626,
#               (6, 7): -0.23588419565289626,
#               (6, 9): -0.2299568541948447,
#               (7, 1): -0.2299568541948447,
#               (7, 5): -0.2299568541948447,
#               (7, 7): -0.23424962448033393,
#               (7, 9): -0.2299568541948447,
#               (8, 1): -0.23586628565289625,
#               (8, 5): -0.2299568541948447,
#               (8, 7): -0.23244316696452538,
#               (8, 9): -0.2299568541948447},
#              'x-x-3-x-x-2-8-x-7': {(0, 1): -0.1,
#               (0, 5): -0.01,
#               (0, 9): -0.01,
#               (1, 1): -0.01,
#               (1, 5): -0.01,
#               (1, 9): -0.01,
#               (3, 1): -0.01,
#               (3, 5): -0.01,
#               (3, 9): -0.01,
#               (4, 1): -0.01,
#               (4, 5): 0,
#               (4, 9): 0,
#               (7, 1): 0,
#               (7, 5): 0,
#               (7, 9): 0},
#              'x-4-3-1-x-2-8-x-7': {(0, 5): 0,
#               (0, 9): 0,
#               (4, 5): 0,
#               (4, 9): -0.1,
#               (7, 5): 0,
#               (7, 9): 0},
#              '6-4-3-1-9-2-8-x-7': {(7, 5): 0},
#              '9-x-8-x-x-x-x-x-x': {(1, 1): -0.2452807127963673,
#               (1, 3): -0.24337512890382987,
#               (1, 5): -0.2427892182355306,
#               (1, 7): -0.2428387989772913,
#               (3, 1): -0.24450666027719015,
#               (3, 3): -0.2417870215619064,
#               (3, 5): -0.2493170101594036,
#               (3, 7): -0.24875777523979797,
#               (4, 1): -0.2452807127963673,
#               (4, 3): -0.33615680661607317,
#               (4, 5): -0.24606668143319685,
#               (4, 7): -0.2444161763873673,
#               (5, 1): -0.28836941046095405,
#               (5, 3): -0.24682952172344008,
#               (5, 5): -0.24452206392232173,
#               (5, 7): -0.24693869227836898,
#               (6, 1): -0.2815102132535777,
#               (6, 3): -0.26383137616441327,
#               (6, 5): -0.3328582591987421,
#               (6, 7): -0.2452807127963673,
#               (7, 1): -0.2452807127963673,
#               (7, 3): -0.2452807127963673,
#               (7, 5): -0.2452807127963673,
#               (7, 7): -0.2452807127963673,
#               (8, 1): -0.2747179249911955,
#               (8, 3): -0.24526087700436397,
#               (8, 5): -0.24189724732175824,
#               (8, 7): -0.24354290728736727},
#              '9-x-8-x-x-x-5-x-6': {(1, 1): -0.01,
#               (1, 3): -0.1,
#               (1, 7): -0.1,
#               (3, 1): 0,
#               (3, 3): 0,
#               (3, 7): 0,
#               (4, 1): 0,
#               (4, 3): 0,
#               (4, 7): 0,
#               (5, 1): 0,
#               (5, 3): 0,
#               (5, 7): 0,
#               (7, 1): 0,
#               (7, 3): 0,
#               (7, 7): 0},
#              '9-7-8-x-x-x-5-4-6': {(3, 1): 0,
#               (3, 3): 0,
#               (4, 1): 0,
#               (4, 3): 0,
#               (5, 1): 0,
#               (5, 3): 0},
#              '8-x-x-x-x-5-x-x-x': {(1, 1): -0.2435253536963673,
#               (1, 3): -0.26383137616441327,
#               (1, 7): -0.23765728565289626,
#               (1, 9): -0.2429816994091592,
#               (2, 1): -0.2409426879277022,
#               (2, 3): -0.2404865895454658,
#               (2, 7): -0.24177846265145728,
#               (2, 9): -0.23851568028892042,
#               (3, 1): -0.31424673693097027,
#               (3, 3): -0.23777749662462327,
#               (3, 7): -0.23889890213039655,
#               (3, 9): -0.24070489287800764,
#               (4, 1): -0.24050788263317513,
#               (4, 3): -0.23826526430463912,
#               (4, 7): -0.2413078520765683,
#               (4, 9): -0.24352547627936558,
#               (6, 1): -0.24294156555064333,
#               (6, 3): -0.24013688349886939,
#               (6, 7): -0.23765728565289626,
#               (6, 9): -0.23940157501268372,
#               (7, 1): -0.24171992071620332,
#               (7, 3): -0.24120576985723213,
#               (7, 7): -0.243295110985868,
#               (7, 9): -0.24144847227897898,
#               (8, 1): -0.25370894647207987,
#               (8, 3): -0.30134435369540774,
#               (8, 7): -0.24227258346143524,
#               (8, 9): -0.24194050896973873},
#              '8-4-3-x-x-5-x-x-x': {(3, 1): 0,
#               (3, 7): 0,
#               (3, 9): 0,
#               (4, 1): 0,
#               (4, 7): 0,
#               (4, 9): 0,
#               (6, 1): 0,
#               (6, 7): 0,
#               (6, 9): 0,
#               (7, 1): 0,
#               (7, 7): 0,
#               (7, 9): 0,
#               (8, 1): 0,
#               (8, 7): 0,
#               (8, 9): 0},
#              'x-x-x-4-x-7-x-x-x': {(0, 1): -0.23765728565289626,
#               (0, 3): -0.30971628381316313,
#               (0, 5): -0.23675122890512434,
#               (0, 9): -0.2909420382838707,
#               (1, 1): -0.23400289465649723,
#               (1, 3): -0.23239049909898626,
#               (1, 5): -0.23151446059690095,
#               (1, 9): -0.23241722999898623,
#               (2, 1): -0.230096545794159,
#               (2, 3): -0.23678401655289624,
#               (2, 5): -0.23508441442140418,
#               (2, 9): -0.23728875608610153,
#               (4, 1): -0.23299532142394383,
#               (4, 3): -0.2334809948853062,
#               (4, 5): -0.23693581812231115,
#               (4, 9): -0.23523979097201095,
#               (6, 1): -0.23765728565289626,
#               (6, 3): -0.3146748588048015,
#               (6, 5): -0.23327544235121436,
#               (6, 9): -0.23764222890512438,
#               (7, 1): -0.23338707030324174,
#               (7, 3): -0.23196249769076932,
#               (7, 5): -0.2368099535184353,
#               (7, 9): -0.23438490160883507,
#               (8, 1): -0.23274581712367332,
#               (8, 3): -0.23684045251945304,
#               (8, 5): -0.2299568541948447,
#               (8, 9): -0.2299568541948447},
#              '8-x-x-4-x-7-1-x-x': {(1, 3): -0.01,
#               (1, 5): -0.01,
#               (1, 9): -0.01,
#               (2, 3): -0.01,
#               (2, 5): -0.01,
#               (2, 9): 0,
#               (4, 3): 0,
#               (4, 5): 0,
#               (4, 9): 0,
#               (7, 3): 0,
#               (7, 5): 0,
#               (7, 9): 0,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '8-x-3-4-2-7-1-x-x': {(1, 5): 0,
#               (1, 9): 0,
#               (7, 5): 0,
#               (7, 9): 0,
#               (8, 5): 0.1,
#               (8, 9): 0},
#              '8-x-3-4-2-7-1-x-5': {(1, 9): 0, (7, 9): 0},
#              '4-x-7-x-x-x-x-x-x': {(1, 1): -0.27507875588477554,
#               (1, 3): -0.26994303183784873,
#               (1, 5): -0.27246910872831454,
#               (1, 9): -0.2722609199635076,
#               (3, 1): -0.2683686865226679,
#               (3, 3): -0.2690864617002078,
#               (3, 5): -0.27161151146090123,
#               (3, 9): -0.27335033500404493,
#               (4, 1): -0.2742835477983088,
#               (4, 3): -0.26819724819587976,
#               (4, 5): -0.3428279056684036,
#               (4, 9): -0.2741580130903705,
#               (5, 1): -0.2717051658877793,
#               (5, 3): -0.2715264994331464,
#               (5, 5): -0.26894964898941637,
#               (5, 9): -0.2726021693612611,
#               (6, 1): -0.27501966404214634,
#               (6, 3): -0.34776837519693793,
#               (6, 5): -0.33344678592419685,
#               (6, 9): -0.2685467033027692,
#               (7, 1): -0.2742138596133135,
#               (7, 3): -0.27501966404214634,
#               (7, 5): -0.27501966404214634,
#               (7, 9): -0.27074868127440455,
#               (8, 1): -0.27501966404214634,
#               (8, 3): -0.3376241964732671,
#               (8, 5): -0.31993661565591675,
#               (8, 9): -0.27085257466202595},
#              '4-x-7-x-3-x-6-x-x': {(1, 1): 0,
#               (1, 5): 0,
#               (1, 9): 0,
#               (3, 1): 0,
#               (3, 5): 1.1361512828387073,
#               (3, 9): 0,
#               (5, 1): 0,
#               (5, 5): 0,
#               (5, 9): 0,
#               (7, 1): 0,
#               (7, 5): 0,
#               (7, 9): 0,
#               (8, 1): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '4-x-7-5-3-x-6-x-x': {(1, 1): 0,
#               (1, 9): 0,
#               (5, 1): 0,
#               (5, 9): 0,
#               (7, 1): 0,
#               (7, 9): 0,
#               (8, 1): 0,
#               (8, 9): 0},
#              '3-x-x-x-x-6-x-x-x': {(1, 1): -0.23695395110793205,
#               (1, 5): -0.2318739542438985,
#               (1, 7): -0.23630879638634383,
#               (1, 9): -0.23475009572143188,
#               (2, 1): -0.32242811021675344,
#               (2, 5): -0.23177782075059702,
#               (2, 7): -0.2535125134167855,
#               (2, 9): -0.23156729080517585,
#               (3, 1): -0.235846760599,
#               (3, 5): -0.23675122890512434,
#               (3, 7): -0.23769489677066347,
#               (3, 9): -0.23431845895759865,
#               (4, 1): -0.23446205853378907,
#               (4, 5): -0.23579561134025462,
#               (4, 7): -0.2462094744816122,
#               (4, 9): -0.23609233186057577,
#               (6, 1): -0.23676628565289626,
#               (6, 5): -0.23715485153430152,
#               (6, 7): -0.23832671327494936,
#               (6, 9): -0.23679274924389626,
#               (7, 1): -0.23765728565289626,
#               (7, 5): -0.23765728565289626,
#               (7, 7): -0.23765728565289626,
#               (7, 9): -0.23765728565289626,
#               (8, 1): -0.23765728565289626,
#               (8, 5): -0.23242811021675347,
#               (8, 7): -0.23845119336686552,
#               (8, 9): -0.23765728565289626},
#              '3-x-x-x-x-6-8-x-9': {(1, 1): -0.01,
#               (1, 5): -0.01,
#               (1, 7): -0.01,
#               (2, 1): -0.01,
#               (2, 5): -0.01,
#               (2, 7): -0.1,
#               (3, 1): -0.01,
#               (3, 5): -0.01,
#               (3, 7): -0.01,
#               (4, 1): -0.01,
#               (4, 5): 0,
#               (4, 7): 0,
#               (7, 1): 0,
#               (7, 5): 0,
#               (7, 7): 0},
#              '3-1-x-x-x-6-8-4-9': {(2, 5): -0.01,
#               (2, 7): -0.01,
#               (3, 5): -0.01,
#               (3, 7): 0,
#               (4, 5): 0,
#               (4, 7): 0},
#              '3-1-7-x-2-6-8-4-9': {(3, 5): 0.0},
#              'x-x-x-4-x-x-x-5-x': {(0, 1): -0.2443807127963673,
#               (0, 3): -0.2502194519960024,
#               (0, 7): -0.2452807127963673,
#               (0, 9): -0.2452807127963673,
#               (1, 1): -0.24382669322931944,
#               (1, 3): -0.24464904814764027,
#               (1, 7): -0.2445689682385417,
#               (1, 9): -0.2436621975845353,
#               (2, 1): -0.24736966218250978,
#               (2, 3): -0.2452807127963673,
#               (2, 7): -0.24853594403558266,
#               (2, 9): -0.2443986227963673,
#               (4, 1): -0.24409237442435014,
#               (4, 3): -0.24751906388112416,
#               (4, 7): -0.24363810512197723,
#               (4, 9): -0.25139001940113725,
#               (5, 1): -0.250484685951434,
#               (5, 3): -0.27033376038219553,
#               (5, 7): -0.24364460340612407,
#               (5, 9): -0.2503977692690129,
#               (6, 1): -0.2452807127963673,
#               (6, 3): -0.2452807127963673,
#               (6, 7): -0.25105481566840365,
#               (6, 9): -0.26383137616441327,
#               (8, 1): -0.24455195771496815,
#               (8, 3): -0.247638520175203,
#               (8, 7): -0.2477349259970213,
#               (8, 9): -0.2452807127963673},
#              'x-x-x-4-3-x-x-5-6': {(0, 1): -0.1,
#               (0, 7): -0.1,
#               (0, 9): -0.01,
#               (1, 1): -0.01,
#               (1, 7): 0,
#               (1, 9): -0.01,
#               (2, 1): 0,
#               (2, 7): 0,
#               (2, 9): 0,
#               (5, 1): 0,
#               (5, 7): 0,
#               (5, 9): 0,
#               (6, 1): 0,
#               (6, 7): 0,
#               (6, 9): 0},
#              'x-9-x-4-3-x-8-5-6': {(0, 1): 0,
#               (0, 7): 0,
#               (2, 1): 0,
#               (2, 7): 0,
#               (5, 1): -0.01,
#               (5, 7): 0},
#              'x-9-2-4-3-1-8-5-6': {(0, 7): 0.0},
#              'x-x-x-x-3-x-8-x-x': {(0, 1): -0.3675990417787415,
#               (0, 5): -0.32446205853378907,
#               (0, 7): -0.31384273550647385,
#               (0, 9): -0.3131829929543324,
#               (1, 1): -0.3082848247962807,
#               (1, 5): -0.4027085108199592,
#               (1, 7): -0.36168056534907705,
#               (1, 9): -0.31274390096397975,
#               (2, 1): -0.3100895750113566,
#               (2, 5): -0.3136056403218119,
#               (2, 7): -0.3137158845259377,
#               (2, 9): -0.31249865744108085,
#               (3, 1): -0.38903442317562453,
#               (3, 5): -0.347199300933277,
#               (3, 7): -0.3145845959188313,
#               (3, 9): -0.3819539628036611,
#               (5, 1): -0.31269763904387454,
#               (5, 5): -0.38292587151427615,
#               (5, 7): -0.3443531987284737,
#               (5, 9): -0.40408303991285244,
#               (7, 1): -0.3114925128944895,
#               (7, 5): -0.38209127375182445,
#               (7, 7): -0.30941380181722045,
#               (7, 9): -0.3078836910831254,
#               (8, 1): -0.36538450083729224,
#               (8, 5): -0.3609359057750794,
#               (8, 7): -0.39253099663296137,
#               (8, 9): -0.3134582971736649},
#              'x-4-5-x-3-x-8-x-x': {(0, 1): -0.01,
#               (0, 7): -0.01,
#               (0, 9): -0.01,
#               (3, 1): -0.1,
#               (3, 7): -0.01,
#               (3, 9): -0.01,
#               (5, 1): 0,
#               (5, 7): 0,
#               (5, 9): 0,
#               (7, 1): -0.1,
#               (7, 7): -0.01,
#               (7, 9): 0,
#               (8, 1): 0,
#               (8, 7): 0,
#               (8, 9): 0},
#              'x-4-5-x-3-x-8-1-6': {(0, 7): 0,
#               (0, 9): 0,
#               (3, 7): 0,
#               (3, 9): 0,
#               (5, 7): 0,
#               (5, 9): 0},
#              'x-x-x-7-x-8-x-x-x': {(0, 1): -0.23508900991891116,
#               (0, 3): -0.23342745895759864,
#               (0, 5): -0.23075750264240907,
#               (0, 9): -0.23765728565289626,
#               (1, 1): -0.2299568541948447,
#               (1, 3): -0.23523091153453637,
#               (1, 5): -0.2299568541948447,
#               (1, 9): -0.23420512212406341,
#               (2, 1): -0.28027213177874144,
#               (2, 3): -0.28027213177874144,
#               (2, 5): -0.300687977001032,
#               (2, 9): -0.2299568541948447,
#               (4, 1): -0.23683512013016098,
#               (4, 3): -0.2299568541948447,
#               (4, 5): -0.2299568541948447,
#               (4, 9): -0.2299568541948447,
#               (6, 1): -0.2299568541948447,
#               (6, 3): -0.23063768182265737,
#               (6, 5): -0.2300067393690972,
#               (6, 9): -0.2299568541948447,
#               (7, 1): -0.2299568541948447,
#               (7, 3): -0.2299568541948447,
#               (7, 5): -0.2299568541948447,
#               (7, 9): -0.2299568541948447,
#               (8, 1): -0.2299568541948447,
#               (8, 3): -0.2299568541948447,
#               (8, 5): -0.23158925140363718,
#               (8, 9): -0.2299568541948447},
#              'x-x-x-7-x-8-1-6-x': {(0, 3): -0.01,
#               (0, 5): -0.01,
#               (0, 9): -0.01,
#               (1, 3): -0.01,
#               (1, 5): -0.01,
#               (1, 9): 0,
#               (2, 3): 0,
#               (2, 5): 0,
#               (2, 9): 0,
#               (4, 3): -0.01,
#               (4, 5): 0,
#               (4, 9): 0,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '4-x-x-7-3-8-1-6-x': {(1, 5): -0.01,
#               (1, 9): 0,
#               (2, 5): 0,
#               (2, 9): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '4-5-2-7-3-8-1-6-x': {(8, 9): 0.0},
#              'x-8-7-x-x-x-x-x-x': {(0, 1): -0.26029962661171957,
#               (0, 3): -0.26029962661171957,
#               (0, 5): -0.2577575446192324,
#               (0, 9): -0.26029962661171957,
#               (3, 1): -0.2585086266117196,
#               (3, 3): -0.25360957971336195,
#               (3, 5): -0.26029962661171957,
#               (3, 9): -0.2551714120383333,
#               (4, 1): -0.3412366280821292,
#               (4, 3): -0.30432185919278104,
#               (4, 5): -0.3389376146949212,
#               (4, 9): -0.25282790566840363,
#               (5, 1): -0.25282790566840363,
#               (5, 3): -0.25282790566840363,
#               (5, 5): -0.258789915352369,
#               (5, 9): -0.25282790566840363,
#               (6, 1): -0.25282790566840363,
#               (6, 3): -0.25800759184215105,
#               (6, 5): -0.25282790566840363,
#               (6, 9): -0.25282790566840363,
#               (7, 1): -0.2545822155720799,
#               (7, 3): -0.32056259599000003,
#               (7, 5): -0.25644823854797194,
#               (7, 9): -0.25282790566840363,
#               (8, 1): -0.2594607677986033,
#               (8, 3): -0.25282790566840363,
#               (8, 5): -0.25282790566840363,
#               (8, 9): -0.25282790566840363},
#              'x-8-7-x-9-x-x-4-x': {(0, 1): -0.01,
#               (0, 3): -0.01,
#               (0, 5): -0.01,
#               (3, 1): 0,
#               (3, 3): 0,
#               (3, 5): 0,
#               (5, 1): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (6, 1): 0,
#               (6, 3): 0,
#               (6, 5): -0.01,
#               (8, 1): 0,
#               (8, 3): 0,
#               (8, 5): 0},
#              '6-8-7-x-9-x-5-4-x': {(3, 1): 0,
#               (3, 3): 0,
#               (5, 1): 0,
#               (5, 3): 0,
#               (8, 1): -0.01,
#               (8, 3): 0},
#              '6-8-7-x-9-2-5-4-1': {(3, 3): 0.0},
#              'x-9-x-x-2-x-x-x-x': {(0, 1): -0.3089749267413304,
#               (0, 3): -0.30869873580342283,
#               (0, 5): -0.3410078747120793,
#               (0, 7): -0.3063968465532616,
#               (2, 1): -0.397687861249656,
#               (2, 3): -0.3579725345568061,
#               (2, 5): -0.37858193721164973,
#               (2, 7): -0.391648769192781,
#               (3, 1): -0.3127968703157465,
#               (3, 3): -0.33855437272994915,
#               (3, 5): -0.3068432917220217,
#               (3, 7): -0.3344631306198195,
#               (5, 1): -0.31251325817240166,
#               (5, 3): -0.35430961467629685,
#               (5, 5): -0.30594329172202167,
#               (5, 7): -0.3804818691909878,
#               (6, 1): -0.30653294487424754,
#               (6, 3): -0.3079858472506916,
#               (6, 5): -0.3090269876272792,
#               (6, 7): -0.35186770085722074,
#               (7, 1): -0.31275152005429235,
#               (7, 3): -0.3081312781809145,
#               (7, 5): -0.30619268648746106,
#               (7, 7): -0.31158192178807936,
#               (8, 1): -0.30792528381316314,
#               (8, 3): -0.310550914130922,
#               (8, 5): -0.36734630253086115,
#               (8, 7): -0.35028501706441334},
#              'x-9-5-x-2-x-x-8-x': {(0, 1): 1.0466174574128355,
#               (0, 3): 0,
#               (0, 7): 0,
#               (3, 1): 0,
#               (3, 3): -0.01,
#               (3, 7): 0,
#               (5, 1): 0,
#               (5, 3): 0,
#               (5, 7): 0,
#               (6, 1): 0,
#               (6, 3): 0,
#               (6, 7): 0,
#               (8, 1): 0,
#               (8, 3): 0,
#               (8, 7): 0},
#              'x-9-5-3-2-x-x-8-6': {(0, 1): 0.1,
#               (0, 7): 0,
#               (5, 1): -0.01,
#               (5, 7): 0,
#               (6, 1): 0,
#               (6, 7): 0},
#              'x-9-5-3-2-1-4-8-6': {(0, 7): 0.1},
#              'x-x-x-2-x-x-x-1-x': {(0, 3): -0.26029962661171957,
#               (0, 5): -0.3352807127963673,
#               (0, 7): -0.2602850170644133,
#               (0, 9): -0.2585776338279882,
#               (1, 3): -0.25873115411665587,
#               (1, 5): -0.260172702960065,
#               (1, 7): -0.25559306915196883,
#               (1, 9): -0.2570923630101352,
#               (2, 3): -0.25648405394768403,
#               (2, 5): -0.25744063040165777,
#               (2, 7): -0.25773186702334866,
#               (2, 9): -0.2551711382882604,
#               (4, 3): -0.26070601240938807,
#               (4, 5): -0.34029899129732893,
#               (4, 7): -0.25458623854991236,
#               (4, 9): -0.25835955644700015,
#               (5, 3): -0.25404474224191015,
#               (5, 5): -0.34293704362730876,
#               (5, 7): -0.26029962661171957,
#               (5, 9): -0.2736142186729999,
#               (6, 3): -0.26029962661171957,
#               (6, 5): -0.25771725747604235,
#               (6, 7): -0.26029962661171957,
#               (6, 9): -0.3043012097295345,
#               (8, 3): -0.25920994105100104,
#               (8, 5): -0.25875926209855704,
#               (8, 7): -0.26029962661171957,
#               (8, 9): -0.25872798645952844},
#              '7-6-x-2-x-x-x-1-x': {(2, 3): -0.01,
#               (2, 5): -0.01,
#               (2, 9): -0.01,
#               (4, 3): -0.01,
#               (4, 5): 0,
#               (4, 9): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (5, 9): 0,
#               (6, 3): -0.01,
#               (6, 5): 0,
#               (6, 9): 0,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '7-6-4-2-x-x-3-1-x': {(4, 5): 0,
#               (4, 9): -0.01,
#               (5, 5): 0,
#               (5, 9): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '7-6-4-2-9-8-3-1-x': {(8, 5): 0.0},
#              'x-9-x-x-x-x-2-x-x': {(0, 1): -0.2348381375789346,
#               (0, 3): -0.23926284424997013,
#               (0, 5): -0.2473845690271776,
#               (0, 7): -0.2646917525163591,
#               (2, 1): -0.23510074054741595,
#               (2, 3): -0.2385514923395582,
#               (2, 5): -0.31595340968045493,
#               (2, 7): -0.24179002006216313,
#               (3, 1): -0.23920205769899638,
#               (3, 3): -0.2368986367788507,
#               (3, 5): -0.23675728565289628,
#               (3, 7): -0.23499586980512435,
#               (4, 1): -0.23899256457608278,
#               (4, 3): -0.23932584991450176,
#               (4, 5): -0.2403796324394512,
#               (4, 7): -0.23886718862234407,
#               (5, 1): -0.2409899498240735,
#               (5, 3): -0.24112393500071527,
#               (5, 5): -0.23511429190334726,
#               (5, 7): -0.23511520366040903,
#               (7, 1): -0.23955779833337248,
#               (7, 3): -0.23787873145457536,
#               (7, 5): -0.24622633639108799,
#               (7, 7): -0.2359504707179617,
#               (8, 1): -0.23950636752347393,
#               (8, 3): -0.2350299089045301,
#               (8, 5): -0.2404094879632908,
#               (8, 7): -0.2409426879277022},
#              '6-9-3-x-x-x-2-x-x': {(3, 1): -0.01,
#               (3, 5): -0.01,
#               (3, 7): 0.29701,
#               (4, 1): 0,
#               (4, 5): -0.01,
#               (4, 7): 0,
#               (5, 1): 0,
#               (5, 5): 0,
#               (5, 7): 0,
#               (7, 1): 0,
#               (7, 5): 0,
#               (7, 7): 0,
#               (8, 1): 0,
#               (8, 5): 0,
#               (8, 7): 0},
#              '6-9-3-x-5-8-2-x-x': {(3, 1): -0.1,
#               (3, 7): 0.1,
#               (7, 1): 0,
#               (7, 7): 0,
#               (8, 1): 0,
#               (8, 7): 0},
#              '6-9-3-1-5-8-2-x-4': {(7, 7): 0},
#              'x-x-x-3-2-x-x-x-x': {(0, 1): -0.2813012767587058,
#               (0, 5): -0.2772045109447201,
#               (0, 7): -0.27932438664128356,
#               (0, 9): -0.31839291149050236,
#               (1, 1): -0.28223985486148306,
#               (1, 5): -0.36501966404214636,
#               (1, 7): -0.27718189356833517,
#               (1, 9): -0.2757265542345204,
#               (2, 1): -0.2773597290085151,
#               (2, 5): -0.3664889338801844,
#               (2, 7): -0.28284987114364957,
#               (2, 9): -0.2814583801368689,
#               (5, 1): -0.2784436711263377,
#               (5, 5): -0.2823990795236729,
#               (5, 7): -0.2781652707891043,
#               (5, 9): -0.27602808039919224,
#               (6, 1): -0.27818074889923694,
#               (6, 5): -0.2772993412581545,
#               (6, 7): -0.2905603498788397,
#               (6, 9): -0.35032822266343994,
#               (7, 1): -0.27663221947422095,
#               (7, 5): -0.29808545954712207,
#               (7, 7): -0.3317678655391,
#               (7, 9): -0.36893064070642734,
#               (8, 1): -0.28056624422235404,
#               (8, 5): -0.28050970479252474,
#               (8, 7): -0.36914797390874815,
#               (8, 9): -0.34201849931362127},
#              'x-x-x-3-2-5-6-x-x': {(0, 1): -0.01,
#               (0, 7): -0.01,
#               (0, 9): -0.01,
#               (1, 1): -0.01,
#               (1, 7): -0.01,
#               (1, 9): -0.01,
#               (2, 1): 0,
#               (2, 7): 0,
#               (2, 9): 0,
#               (7, 1): 0,
#               (7, 7): 0,
#               (7, 9): 0,
#               (8, 1): 0,
#               (8, 7): -0.01,
#               (8, 9): 0},
#              '4-x-x-3-2-5-6-x-7': {(1, 1): 0,
#               (1, 9): 0,
#               (2, 1): 0,
#               (2, 9): -0.01,
#               (7, 1): 0,
#               (7, 9): 0},
#              '4-8-9-3-2-5-6-x-7': {(7, 1): 0.0},
#              'x-4-1-x-x-x-x-x-x': {(0, 3): -0.24356028534245724,
#               (0, 5): -0.2452807127963673,
#               (0, 7): -0.24941715737206285,
#               (0, 9): -0.2452807127963673,
#               (3, 3): -0.24448296641182277,
#               (3, 5): -0.2443807127963673,
#               (3, 7): -0.2452807127963673,
#               (3, 9): -0.24445024257138218,
#               (4, 3): -0.24526580661607314,
#               (4, 5): -0.30432185919278104,
#               (4, 7): -0.2452807127963673,
#               (4, 9): -0.24526580661607314,
#               (5, 3): -0.2452807127963673,
#               (5, 5): -0.2452807127963673,
#               (5, 7): -0.2452807127963673,
#               (5, 9): -0.2436609645000265,
#               (6, 3): -0.2452807127963673,
#               (6, 5): -0.24445024257138218,
#               (6, 7): -0.2452807127963673,
#               (6, 9): -0.24714419924636602,
#               (7, 3): -0.24438829299301001,
#               (7, 5): -0.30432185919278104,
#               (7, 7): -0.2452807127963673,
#               (7, 9): -0.2452807127963673,
#               (8, 3): -0.2452807127963673,
#               (8, 5): -0.24942128726691642,
#               (8, 7): -0.2452807127963673,
#               (8, 9): -0.24352517638736726},
#              '8-4-1-x-x-x-3-x-x': {(3, 5): -0.01,
#               (3, 7): -0.01,
#               (3, 9): -0.01,
#               (4, 5): 0,
#               (4, 7): 0,
#               (4, 9): 0,
#               (5, 5): 0,
#               (5, 7): 0,
#               (5, 9): 0,
#               (7, 5): 0,
#               (7, 7): 0,
#               (7, 9): 0,
#               (8, 5): -0.01,
#               (8, 7): 0,
#               (8, 9): 0},
#              '8-4-1-x-x-2-3-x-5': {(3, 7): 0,
#               (3, 9): 0,
#               (4, 7): 0,
#               (4, 9): 0,
#               (7, 7): 0.1,
#               (7, 9): 0},
#              '8-4-1-x-x-2-3-7-5': {(3, 9): 0, (4, 9): 0},
#              'x-x-x-x-2-x-x-9-x': {(0, 1): -0.34274737540436784,
#               (0, 3): -0.402012461798099,
#               (0, 5): -0.3464449495700754,
#               (0, 7): -0.34103987944991243,
#               (1, 1): -0.34602742946126686,
#               (1, 3): -0.3461024461454309,
#               (1, 5): -0.34435128133471565,
#               (1, 7): -0.3442183691860492,
#               (2, 1): -0.4008421422345209,
#               (2, 3): -0.41268596471408325,
#               (2, 5): -0.3459786527307609,
#               (2, 7): -0.34942048065541326,
#               (3, 1): -0.3940839360903981,
#               (3, 3): -0.3401971180618292,
#               (3, 5): -0.36764762705291265,
#               (3, 7): -0.34665732493254614,
#               (5, 1): -0.34279523854991245,
#               (5, 3): -0.3404248109960303,
#               (5, 5): -0.3448455552033108,
#               (5, 7): -0.3467532675117196,
#               (6, 1): -0.3561667823589736,
#               (6, 3): -0.3440867449194953,
#               (6, 5): -0.3479579498073226,
#               (6, 7): -0.3401548156684036,
#               (8, 1): -0.3650872980148112,
#               (8, 3): -0.3402194519960024,
#               (8, 5): -0.3459222747279882,
#               (8, 7): -0.375696320460954},
#              'x-x-x-4-2-5-x-9-x': {(0, 1): -0.01,
#               (0, 3): -0.01,
#               (0, 7): -0.01,
#               (1, 1): -0.01,
#               (1, 3): -0.01,
#               (1, 7): -0.01,
#               (2, 1): -0.01,
#               (2, 3): -0.01,
#               (2, 7): 0,
#               (6, 1): 0,
#               (6, 3): -0.01,
#               (6, 7): 0,
#               (8, 1): 0,
#               (8, 3): 0,
#               (8, 7): 0},
#              'x-x-x-4-2-5-3-9-6': {(0, 1): 0,
#               (0, 7): 0,
#               (1, 1): 0,
#               (1, 7): -0.1,
#               (2, 1): 0,
#               (2, 7): 0},
#              '8-7-x-4-2-5-3-9-6': {(2, 1): 0},
#              '6-x-x-x-x-x-x-x-1': {(1, 3): -0.32427095093971664,
#               (1, 5): -0.3560434772647232,
#               (1, 7): -0.3291881433198195,
#               (1, 9): -0.3279341441989115,
#               (2, 3): -0.3291665941079964,
#               (2, 5): -0.32408206949935764,
#               (2, 7): -0.3840964976472327,
#               (2, 9): -0.3296035097341836,
#               (3, 3): -0.34860168797070323,
#               (3, 5): -0.32320895509,
#               (3, 7): -0.3228633631307094,
#               (3, 9): -0.342967940425125,
#               (4, 3): -0.32355773426063156,
#               (4, 5): -0.32805677315821297,
#               (4, 7): -0.326212441434831,
#               (4, 9): -0.3275405059047983,
#               (5, 3): -0.3932023823812894,
#               (5, 5): -0.40647700793010144,
#               (5, 7): -0.3352807127963673,
#               (5, 9): -0.388905887001032,
#               (6, 3): -0.3346189151381986,
#               (6, 5): -0.32404029785786553,
#               (6, 7): -0.3308768655391,
#               (6, 9): -0.3268904707236406,
#               (7, 3): -0.3719649496927749,
#               (7, 5): -0.32342361880525566,
#               (7, 7): -0.3287975110397249,
#               (7, 9): -0.3753135880675318},
#              '6-x-x-2-x-x-x-9-1': {(1, 3): -0.01,
#               (1, 5): -0.01,
#               (1, 7): -0.1,
#               (2, 3): -0.01,
#               (2, 5): -0.01,
#               (2, 7): -0.01,
#               (4, 3): -0.01,
#               (4, 5): -0.01,
#               (4, 7): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (5, 7): 0,
#               (6, 3): 0,
#               (6, 5): 0,
#               (6, 7): 0},
#              '6-x-3-2-4-x-x-9-1': {(1, 5): 0,
#               (1, 7): 0,
#               (5, 5): 0,
#               (5, 7): 0,
#               (6, 5): 0,
#               (6, 7): 0.1},
#              '6-x-3-2-4-x-7-9-1': {(1, 5): 0, (5, 5): 0},
#              'x-x-x-5-x-x-x-8-x': {(0, 1): -0.2635517739685715,
#               (0, 3): -0.2586635172214764,
#               (0, 7): -0.26014133311003884,
#               (0, 9): -0.259998694037633,
#               (1, 1): -0.3301038291145859,
#               (1, 3): -0.2594983143204851,
#               (1, 7): -0.26029962661171957,
#               (1, 9): -0.26029962661171957,
#               (2, 1): -0.2585265366117196,
#               (2, 3): -0.26113313310203873,
#               (2, 7): -0.2643568019685707,
#               (2, 9): -0.2617451836992972,
#               (4, 1): -0.3352807127963673,
#               (4, 3): -0.27209306240276915,
#               (4, 7): -0.26029962661171957,
#               (4, 9): -0.26029962661171957,
#               (5, 1): -0.25765326751171963,
#               (5, 3): -0.26029962661171957,
#               (5, 7): -0.2585086266117196,
#               (5, 9): -0.2592572475549721,
#               (6, 1): -0.26334601974891464,
#               (6, 3): -0.32333539504452596,
#               (6, 7): -0.2597784596649211,
#               (6, 9): 0.38765044877997623,
#               (8, 1): -0.2850095150346631,
#               (8, 3): -0.32368800601461195,
#               (8, 7): -0.25827008882691144,
#               (8, 9): -0.264398097941548},
#              'x-x-x-5-x-x-4-8-3': {(0, 1): 0,
#               (0, 7): 0,
#               (0, 9): 0,
# ...
#               (4, 7): -0.01,
#               (4, 9): 0,
#               (6, 5): 0,
#               (6, 7): 0,
#               (6, 9): 0,
#               (8, 5): 0,
#               (8, 7): 0,
#               (8, 9): 0},
#              '1-3-4-x-7-8-x-6-x': {(3, 5): -0.01,
#               (3, 9): -0.01,
#               (6, 5): -0.01,
#               (6, 9): -0.0091,
#               (8, 5): 0,
#               (8, 9): 0},
#              '1-3-4-x-7-8-5-6-2': {(3, 9): 0.29701},
#              'x-x-6-8-x-x-9-1-x': {(0, 3): -0.01,
#               (0, 5): -0.01,
#               (0, 7): -0.1,
#               (1, 3): -0.01,
#               (1, 5): -0.01,
#               (1, 7): -0.01,
#               (4, 3): -0.01,
#               (4, 5): -0.1,
#               (4, 7): -0.01,
#               (5, 3): -0.1,
#               (5, 5): -0.01,
#               (5, 7): -0.1,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 7): 0},
#              '7-2-6-8-x-x-9-1-x': {(4, 3): 0,
#               (4, 5): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (8, 3): 0,
#               (8, 5): 0},
#              'x-x-3-x-x-x-x-6-x': {(0, 1): -0.24776820138955405,
#               (0, 5): -0.2464762006280771,
#               (0, 7): -0.24562811193764583,
#               (0, 9): -0.2496468022811955,
#               (1, 1): -0.3402194519960024,
#               (1, 5): -0.24460849460516856,
#               (1, 7): -0.3403119995965448,
#               (1, 9): -0.2452807127963673,
#               (3, 1): -0.2519458156684036,
#               (3, 5): -0.25198904685528734,
#               (3, 7): -0.24856966162666294,
#               (3, 9): -0.24630007840264193,
#               (4, 1): -0.2452807127963673,
#               (4, 5): -0.28836941046095405,
#               (4, 7): -0.2502194519960024,
#               (4, 9): -0.2452807127963673,
#               (5, 1): -0.24448296641182277,
#               (5, 5): -0.25122435485502626,
#               (5, 7): -0.24449094387566822,
#               (5, 9): -0.2512081573720628,
#               (6, 1): -0.24526580661607314,
#               (6, 5): -0.2841955711671552,
#               (6, 7): -0.28027213177874144,
#               (6, 9): -0.24876381836601344,
#               (8, 1): -0.2495067692690129,
#               (8, 5): -0.26383137616441327,
#               (8, 7): -0.2459671913941128,
#               (8, 9): -0.24571168801390833},
#              '1-2-3-x-x-x-x-6-x': {(3, 5): -0.01,
#               (3, 7): -0.01,
#               (3, 9): -0.01,
#               (4, 5): -0.01,
#               (4, 7): 0.490099501,
#               (4, 9): 0,
#               (5, 5): 0,
#               (5, 7): 0,
#               (5, 9): 0,
#               (6, 5): 0,
#               (6, 7): 0,
#               (6, 9): 0,
#               (8, 5): 0,
#               (8, 7): 0,
#               (8, 9): 0},
#              '1-2-3-5-8-x-x-6-x': {(5, 7): -0.1,
#               (5, 9): 0,
#               (6, 7): 0,
#               (6, 9): 0,
#               (8, 7): 0,
#               (8, 9): -0.01},
#              '1-2-3-5-8-4-x-6-9': {(6, 7): 0.0},
#              'x-x-x-x-7-8-x-x-x': {(0, 1): -0.24370907264417616,
#               (0, 3): -0.2452807127963673,
#               (0, 5): -0.24642187208479543,
#               (0, 9): -0.2435076227963673,
#               (1, 1): -0.24769726186306285,
#               (1, 3): -0.2452807127963673,
#               (1, 5): -0.2435074436963673,
#               (1, 9): -0.2411077824008947,
#               (2, 1): -0.2452807127963673,
#               (2, 3): -0.27120702948219555,
#               (2, 5): -0.28583168055739844,
#               (2, 9): -0.2452807127963673,
#               (3, 1): -0.24294330920324955,
#               (3, 3): -0.2452807127963673,
#               (3, 5): -0.2452807127963673,
#               (3, 9): -0.2452807127963673,
#               (6, 1): -0.2452807127963673,
#               (6, 3): -0.24102676226041925,
#               (6, 5): -0.2443807127963673,
#               (6, 9): -0.24359452184879013,
#               (7, 1): -0.2452807127963673,
#               (7, 3): -0.24239119052610827,
#               (7, 5): -0.2436064436963673,
#               (7, 9): -0.2452807127963673,
#               (8, 1): -0.2452807127963673,
#               (8, 3): -0.2650694616388321,
#               (8, 5): -0.2450091581953381,
#               (8, 9): -0.2452807127963673},
#              '1-x-x-6-7-8-x-x-x': {(1, 3): -0.01,
#               (1, 5): -0.0091,
#               (1, 9): -0.01,
#               (2, 3): 0,
#               (2, 5): 0,
#               (2, 9): 0,
#               (6, 3): 0,
#               (6, 5): 0,
#               (6, 9): 0,
#               (7, 3): -0.01,
#               (7, 5): 0,
#               (7, 9): 0,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '1-x-x-6-7-8-x-3-4': {(1, 5): 0.199,
#               (1, 9): 0,
#               (2, 5): 0,
#               (2, 9): 0,
#               (6, 5): 0,
#               (6, 9): 0},
#              '1-5-x-6-7-8-x-3-4': {(2, 9): 0, (6, 9): 0},
#              'x-x-x-x-x-3-x-x-6': {(0, 1): -0.2620403761644132,
#               (0, 5): -0.26462730792394423,
#               (0, 7): -0.2668262758488591,
#               (0, 9): -0.26769663034560237,
#               (1, 1): -0.26582950328945554,
#               (1, 5): -0.26029962661171957,
#               (1, 7): -0.2635965949527359,
#               (1, 9): -0.2608789538142956,
#               (2, 1): -0.264489366744018,
#               (2, 5): -0.264430439038779,
#               (2, 7): -0.2631812146052394,
#               (2, 9): -0.26631154095626997,
#               (3, 1): -0.264045783223281,
#               (3, 5): -0.2632659046418623,
#               (3, 7): -0.26446270739986677,
#               (3, 9): -0.2665015355786504,
#               (4, 1): -0.26029962661171957,
#               (4, 5): -0.30812876850791954,
#               (4, 7): -0.26597894371439823,
#               (4, 9): -0.26029962661171957,
#               (6, 1): -0.26331982079382465,
#               (6, 5): -0.2668262758488591,
#               (6, 7): -0.3500942721839769,
#               (6, 9): -0.26625302342641793,
#               (7, 1): -0.2673221182947051,
#               (7, 5): -0.30432185919278104,
#               (7, 7): -0.2632842929046146,
#               (7, 9): -0.26060965075968373},
#              '4-7-x-x-x-3-x-x-6': {(2, 1): -0.01,
#               (2, 5): -0.01,
#               (2, 9): -0.01,
#               (3, 1): -0.01,
#               (3, 5): -0.01,
#               (3, 9): -0.01,
#               (4, 1): -0.01,
#               (4, 5): 0.1,
#               (4, 9): 0,
#               (6, 1): 0,
#               (6, 5): 0,
#               (6, 9): 0,
#               (7, 1): 0,
#               (7, 5): 0,
#               (7, 9): 0},
#              '4-7-x-x-1-3-x-8-6': {(2, 5): -0.01,
#               (2, 9): 0,
#               (3, 5): 0,
#               (3, 9): -0.1,
#               (6, 5): 0,
#               (6, 9): 0},
#              '4-7-x-9-1-3-2-8-6': {(2, 5): 0},
#              'x-x-2-x-x-x-x-7-x': {(0, 1): -0.26769663034560237,
#               (0, 3): -0.26769663034560237,
#               (0, 5): -0.2918241282838707,
#               (0, 9): -0.27030206240276916,
#               (1, 1): -0.26769663034560237,
#               (1, 3): -0.27236448404214636,
#               (1, 5): -0.2694197933027691,
#               (1, 9): -0.2676773836964574,
#               (3, 1): -0.27244458195702503,
#               (3, 3): -0.26693798147155695,
#               (3, 5): -0.2700070646321527,
#               (3, 9): -0.26835248225464603,
#               (4, 1): -0.2664815401549058,
#               (4, 3): -0.26754811267240786,
#               (4, 5): -0.2686649474897083,
#               (4, 9): -0.32586913890512437,
#               (5, 1): -0.2709932916102334,
#               (5, 3): -0.27326705336945784,
#               (5, 5): -0.2712956893928789,
#               (5, 9): -0.2680042667323299,
#               (6, 1): -0.27307909356577664,
#               (6, 3): -0.27168795123258543,
#               (6, 5): -0.28376174574128354,
#               (6, 9): -0.3368806253007048,
#               (8, 1): -0.2665486943603948,
#               (8, 3): -0.2696387854765617,
#               (8, 5): -0.2684592549279495,
#               (8, 9): -0.29469552927455966},
#              '1-8-2-x-x-x-x-7-x': {(3, 3): -0.01,
#               (3, 5): -0.01,
#               (3, 9): -0.01,
#               (4, 3): -0.01,
#               (4, 5): 0,
#               (4, 9): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (5, 9): -0.01,
#               (6, 3): 0,
#               (6, 5): 0,
#               (6, 9): 0,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 9): 0},
#              '1-8-2-4-x-9-x-7-x': {(4, 3): -0.01,
#               (4, 5): 0,
#               (6, 3): 0,
#               (6, 5): 0,
#               (8, 3): -0.01,
#               (8, 5): 0},
#              '1-8-2-4-x-9-6-7-3': {(4, 5): 0.0},
#              'x-x-x-x-2-x-x-x-9': {(0, 1): -0.310252712291677,
#               (0, 3): -0.3079290300361824,
#               (0, 5): -0.3083124477901723,
#               (0, 7): -0.3110812135654039,
#               (1, 1): -0.30958271908906987,
#               (1, 3): -0.3062183640833448,
#               (1, 5): -0.350881499763236,
#               (1, 7): -0.3933143106771117,
#               (2, 1): -0.3104360321095039,
#               (2, 3): -0.310550914130922,
#               (2, 5): -0.3632587188158315,
#               (2, 7): -0.3077896730095039,
#               (3, 1): -0.3352807127963673,
#               (3, 3): -0.30434357309936605,
#               (3, 5): -0.3932881117220217,
#               (3, 7): -0.35690333117728024,
#               (5, 1): -0.37452462797674324,
#               (5, 3): -0.305225663099366,
#               (5, 5): -0.3402501556917736,
#               (5, 7): -0.36124491860086727,
#               (6, 1): -0.38095305859131984,
#               (6, 3): -0.3058217415993981,
#               (6, 5): -0.3106152333659615,
#               (6, 7): -0.37064921206715523,
#               (7, 1): -0.30814397734405274,
#               (7, 3): -0.310550914130922,
#               (7, 5): -0.39036576375006127,
#               (7, 7): -0.33770279082344007},
#              'x-x-1-x-2-x-x-4-9': {(0, 3): -0.01,
#               (0, 5): -0.01,
#               (0, 7): -0.01,
#               (1, 3): -0.01,
#               (1, 5): -0.01,
#               (1, 7): -0.01,
#               (3, 3): -0.01,
#               (3, 5): 0,
#               (3, 7): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (5, 7): 0,
#               (6, 3): 0,
#               (6, 5): 0,
#               (6, 7): 0},
#              '3-x-1-x-2-6-x-4-9': {(1, 5): -0.01,
#               (1, 7): -0.01,
#               (3, 5): 0,
#               (3, 7): 0,
#               (6, 5): 0,
#               (6, 7): 0},
#              '3-5-1-x-2-6-8-4-9': {(3, 7): 0.3940399},
#              'x-9-x-x-x-x-x-8-x': {(0, 1): -0.2384921895073067,
#               (0, 3): -0.2452807127963673,
#               (0, 5): -0.23840355587763684,
#               (0, 7): -0.2452807127963673,
#               (2, 1): -0.23890465056947557,
#               (2, 3): -0.2452807127963673,
#               (2, 5): -0.23999999442579892,
#               (2, 7): -0.2452807127963673,
#               (3, 1): -0.2452807127963673,
#               (3, 3): -0.2452807127963673,
#               (3, 5): -0.2452807127963673,
#               (3, 7): -0.2452807127963673,
#               (4, 1): -0.2452807127963673,
#               (4, 3): -0.23765728565289626,
#               (4, 5): -0.23765728565289626,
#               (4, 7): -0.23765728565289626,
#               (5, 1): -0.23765728565289626,
#               (5, 3): -0.23765728565289626,
#               (5, 5): -0.23765728565289626,
#               (5, 7): -0.23765728565289626,
#               (6, 1): -0.2436733616991204,
#               (6, 3): -0.24526580661607314,
#               (6, 5): -0.2385422289051244,
#               (6, 7): -0.23765728565289626,
#               (8, 1): -0.24348829299301,
#               (8, 3): -0.23765728565289626,
#               (8, 5): -0.2409426879277022,
#               (8, 7): -0.23765728565289626},
#              '1-9-x-x-2-x-x-8-x': {(2, 3): -0.01,
#               (2, 5): 0.29701,
#               (2, 7): 0,
#               (3, 3): 0,
#               (3, 5): 0,
#               (3, 7): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (5, 7): 0,
#               (6, 3): 0,
#               (6, 5): 0,
#               (6, 7): 0,
#               (8, 3): 0,
#               (8, 5): 0,
#               (8, 7): 0},
#              '1-9-3-4-2-x-x-8-x': {(5, 5): 0,
#               (5, 7): -0.01,
#               (6, 5): 0,
#               (6, 7): 0,
#               (8, 5): 0,
#               (8, 7): 0},
#              '1-9-3-4-2-7-6-8-x': {(8, 5): 0.490099501},
#              'x-x-x-x-x-x-8-x-7': {(0, 1): -0.2299568541948447,
#               (0, 3): -0.22648054101547377,
#               (0, 5): -0.2299568541948447,
#               (0, 9): -0.22566661784801187,
#               (1, 1): -0.22580019789692277,
#               (1, 3): -0.23208583912925515,
#               (1, 5): -0.22956368040880099,
#               (1, 9): -0.23111707470923057,
#               (2, 1): -0.22513676319593312,
#               (2, 3): -0.2627838983401842,
#               (2, 5): -0.2286227904576871,
#               (2, 9): -0.22658782592824758,
#               (3, 1): -0.28836941046095405,
#               (3, 3): -0.22904164535871147,
#               (3, 5): -0.28027213177874144,
#               (3, 9): -0.2299568541948447,
#               (4, 1): -0.23044544764045524,
#               (4, 3): -0.3098339759376614,
#               (4, 5): -0.29635595357891575,
#               (4, 9): -0.23017469240047878,
#               (5, 1): -0.22707812587230186,
#               (5, 3): -0.22625851609919911,
#               (5, 5): -0.22622262876963498,
#               (5, 9): -0.23272264385859867,
#               (7, 1): -0.22831461940509806,
#               (7, 3): -0.22824472628172846,
#               (7, 5): -0.2267564655966836,
#               (7, 9): -0.2302200747934889},
#              '1-x-2-x-x-x-8-x-7': {(1, 3): -0.01,
#               (1, 5): -0.01,
#               (1, 9): -0.01,
#               (3, 3): -0.01,
#               (3, 5): -0.01,
#               (3, 9): -0.01,
#               (4, 3): -0.1,
#               (4, 5): 0.1,
#               (4, 9): 0,
#               (5, 3): 0,
#               (5, 5): 0,
#               (5, 9): 0,
#               (7, 3): 0,
#               (7, 5): 0,
#               (7, 9): 0},
#              '1-9-2-4-x-x-8-x-7': {(4, 3): 0,
#               (4, 5): 0.199,
#               (5, 3): 0,
#               (5, 5): 0,
#               (7, 3): 0,
#               (7, 5): 0},
#              '1-9-2-4-5-x-8-x-7': {(5, 3): 0, (7, 3): 0},
#              'x-x-x-x-4-x-x-3-x': {(0, 1): -0.37395851495195404,
#               (0, 5): -0.35031596596244907,
#               (0, 7): -0.3309426879277022,
#               (0, 9): -0.4050139385771192,
#               (1, 1): -0.32884387025331446,
#               (1, 5): -0.3342070635070163,
#               (1, 7): -0.3330640093573079,
#               (1, 9): -0.32983589416372855,
#               (2, 1): -0.3303318527930983,
#               (2, 5): -0.37536260842625163,
#               (2, 7): -0.3309311305169964,
#               (2, 9): -0.3295601259544658,
#               (3, 1): -0.3692704147910576,
#               (3, 5): -0.3317343536963673,
#               (3, 7): -0.3317343536963673,
#               (3, 9): -0.33030172154692927,
#               (5, 1): -0.3807023052989882,
#               (5, 5): -0.3845947163563445,
#               (5, 7): -0.35546589995500777,
#               (5, 9): -0.3445862385499124,
#               (6, 1): -0.3350896253007048,
#               (6, 5): -0.33277136008592123,
#               (6, 7): -0.3308166227963673,
#               (6, 9): -0.33442947701505665,
#               (8, 1): -0.36248868405226914,
#               (8, 5): -0.3477172574760423,
#               (8, 7): -0.33135407189038973,
#               (8, 9): -0.38411696061255796},
#              'x-5-8-x-4-x-x-3-x': {(0, 1): -0.01,
#               (0, 7): -0.01,
#               (0, 9): -0.01,
#               (3, 1): -0.01,
#               (3, 7): -0.01,
#               (3, 9): -0.1,
#               (5, 1): -0.01,
#               (5, 7): -0.01,
#               (5, 9): -0.01,
#               (6, 1): -0.01,
#               (6, 7): -0.01,
#               (6, 9): 0,
#               (8, 1): 0,
#               (8, 7): 0,
#               (8, 9): 0},
#              ...})

# %%
len(Q_dict)
# Out:
# 1412071

# %%
# try checking for one of the states - that which action your agent thinks is the best  -----This will not be evaluated
print(Q_dict.keys())

max_val = max(Q_dict['x-x-x-x-x-x-x-x-x'].values())

for action, value in Q_dict['x-x-x-x-x-x-x-x-x'].items():
    if value == max_val:
        print(action)
        print(values)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# #### Check the states tracked for Q-values convergence
# (non-evaluative)

# %%
# Write the code for plotting the graphs for state-action pairs tracked
# Out:
# (6, 5)
# -0.03940399
# (1, 9)
# -0.07725530557207991

# %%
plt.figure(0, figsize=(16,7))

x_axis = np.asarray(range(0, len(States_track['x-x-x-x-x-x-x-x-x'][(6,5)])))
plt.subplot(221)
plt.plot(x_axis,np.asarray(States_track['x-x-x-x-x-x-x-x-x'][(6,5)]))
plt.show

x_axis = np.asarray(range(0, len(States_track['x-3-x-x-1-x-x-x-x'][(7,5)])))
plt.subplot(222)
plt.plot(x_axis,np.asarray(States_track['x-3-x-x-1-x-x-x-x'][(7,5)]))
plt.show

x_axis = np.asarray(range(0, len(States_track['x-x-x-x-x-x-x-x-x'][(1,9)])))
plt.subplot(223)
plt.plot(x_axis,np.asarray(States_track['x-x-x-x-x-x-x-x-x'][(1,9)]))
plt.show

x_axis = np.asarray(range(0, len(States_track['x-5-x-x-x-x-5-7-x'][(8,2)])))
plt.subplot(224)
plt.plot(x_axis,np.asarray(States_track['x-5-x-x-x-x-5-7-x'][(8,2)]))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Epsilon - decay check

# %%
max_epsilon = 1.0
min_epsilon = 0.001
time = np.arange(0,5000000)
epsilon = []
for i in range(0,5000000):
    epsilon.append(min_epsilon + (max_epsilon - min_epsilon) * np.exp(-0.000001*i))

# %%
plt.plot(time, epsilon)
plt.show()
