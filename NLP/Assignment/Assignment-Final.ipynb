# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk
import random
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import time
import sys

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# first few tagged sentences
print(nltk_data[:40])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], [('Rudolph', 'NOUN'), ('Agnew', 'NOUN'), (',', '.'), ('55', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), ('and', 'CONJ'), ('former', 'ADJ'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Consolidated', 'NOUN'), ('Gold', 'NOUN'), ('Fields', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('was', 'VERB'), ('named', 'VERB'), ('*-1', 'X'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('British', 'ADJ'), ('industrial', 'ADJ'), ('conglomerate', 'NOUN'), ('.', '.')], [('A', 'DET'), ('form', 'NOUN'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('once', 'ADV'), ('used', 'VERB'), ('*', 'X'), ('*', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('Kent', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('has', 'VERB'), ('caused', 'VERB'), ('a', 'DET'), ('high', 'ADJ'), ('percentage', 'NOUN'), ('of', 'ADP'), ('cancer', 'NOUN'), ('deaths', 'NOUN'), ('among', 'ADP'), ('a', 'DET'), ('group', 'NOUN'), ('of', 'ADP'), ('workers', 'NOUN'), ('exposed', 'VERB'), ('*', 'X'), ('to', 'PRT'), ('it', 'PRON'), ('more', 'ADV'), ('than', 'ADP'), ('30', 'NUM'), ('years', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('researchers', 'NOUN'), ('reported', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('asbestos', 'NOUN'), ('fiber', 'NOUN'), (',', '.'), ('crocidolite', 'NOUN'), (',', '.'), ('is', 'VERB'), ('unusually', 'ADV'), ('resilient', 'ADJ'), ('once', 'ADP'), ('it', 'PRON'), ('enters', 'VERB'), ('the', 'DET'), ('lungs', 'NOUN'), (',', '.'), ('with', 'ADP'), ('even', 'ADV'), ('brief', 'ADJ'), ('exposures', 'NOUN'), ('to', 'PRT'), ('it', 'PRON'), ('causing', 'VERB'), ('symptoms', 'NOUN'), ('that', 'DET'), ('*T*-1', 'X'), ('show', 'VERB'), ('up', 'PRT'), ('decades', 'NOUN'), ('later', 'ADJ'), (',', '.'), ('researchers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-2', 'X'), ('.', '.')], [('Lorillard', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('the', 'DET'), ('unit', 'NOUN'), ('of', 'ADP'), ('New', 'ADJ'), ('York-based', 'ADJ'), ('Loews', 'NOUN'), ('Corp.', 'NOUN'), ('that', 'DET'), ('*T*-2', 'X'), ('makes', 'VERB'), ('Kent', 'NOUN'), ('cigarettes', 'NOUN'), (',', '.'), ('stopped', 'VERB'), ('using', 'VERB'), ('crocidolite', 'NOUN'), ('in', 'ADP'), ('its', 'PRON'), ('Micronite', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('in', 'ADP'), ('1956', 'NUM'), ('.', '.')], [('Although', 'ADP'), ('preliminary', 'ADJ'), ('findings', 'NOUN'), ('were', 'VERB'), ('reported', 'VERB'), ('*-2', 'X'), ('more', 'ADV'), ('than', 'ADP'), ('a', 'DET'), ('year', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('the', 'DET'), ('latest', 'ADJ'), ('results', 'NOUN'), ('appear', 'VERB'), ('in', 'ADP'), ('today', 'NOUN'), ("'s", 'PRT'), ('New', 'NOUN'), ('England', 'NOUN'), ('Journal', 'NOUN'), ('of', 'ADP'), ('Medicine', 'NOUN'), (',', '.'), ('a', 'DET'), ('forum', 'NOUN'), ('likely', 'ADJ'), ('*', 'X'), ('to', 'PRT'), ('bring', 'VERB'), ('new', 'ADJ'), ('attention', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('problem', 'NOUN'), ('.', '.')], [('A', 'DET'), ('Lorillard', 'NOUN'), ('spokewoman', 'NOUN'), ('said', 'VERB'), (',', '.'), ('``', '.'), ('This', 'DET'), ('is', 'VERB'), ('an', 'DET'), ('old', 'ADJ'), ('story', 'NOUN'), ('.', '.')], [('We', 'PRON'), ("'re", 'VERB'), ('talking', 'VERB'), ('about', 'ADP'), ('years', 'NOUN'), ('ago', 'ADP'), ('before', 'ADP'), ('anyone', 'NOUN'), ('heard', 'VERB'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('having', 'VERB'), ('any', 'DET'), ('questionable', 'ADJ'), ('properties', 'NOUN'), ('.', ...

# %%
# Splitting into train and test
train_set, test_set = train_test_split(nltk_data,test_size=0.05,random_state=100)

print(len(train_set))
print(len(test_set))
# Out:
# 3718
# 196

# %%
# Getting list of tagged words
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)
# Out:
# 95949

# %%
train_tagged_words[:5]
# Out:
# [('One', 'NUM'),
#  ('bright', 'ADJ'),
#  ('sign', 'NOUN'),
#  ('is', 'VERB'),
#  ('that', 'ADP')]

# %%
# getting vocabulary
tokens = [pair[0] for pair in train_tagged_words]
vocabulary = set(tokens)
print(len(vocabulary))
# Out:
# 12106

# %%
# number of tags
tags = set([pair[1] for pair in train_tagged_words])
print(len(tags))
tags
# Out:
# 12
# {'.',
#  'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PRT',
#  'VERB',
#  'X'}

# %% [markdown]
# #### Emission Probability

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %% [markdown]
# #### Transiiton Probability Calculation

# %%
# Method to count the tags
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# Transition Probability Calculattion
tags_matrix = np.zeros((len(tags), len(tags)), dtype='float32')
for i, t1 in enumerate(list(tags)):
    for j, t2 in enumerate(list(tags)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
#Corelation
tags_df = pd.DataFrame(tags_matrix, columns = list(tags), index=list(tags))
tags_df
# Out:
#           CONJ      VERB       ADP         .       ADV       ADJ         X  \
# CONJ  0.000464  0.155308  0.053778  0.035698  0.053778  0.118683  0.008809
# VERB  0.005186  0.168744  0.091184  0.034291  0.082050  0.065640  0.218438
# ADP   0.000848  0.008481  0.017492  0.039754  0.013357  0.107389  0.034984
# .     0.058032  0.088708  0.092206  0.092923  0.052292  0.043681  0.026908
# ADV   0.006991  0.344541  0.119507  0.135153  0.077230  0.130160  0.023302
# ADJ   0.016052  0.011794  0.078624  0.063882  0.004914  0.067158  0.020311
# X     0.010316  0.204571  0.144898  0.162831  0.025393  0.016505  0.074433
# PRT   0.002297  0.405184  0.019357  0.043635  0.010171  0.083661  0.013123
# NOUN  0.042921  0.146955  0.177058  0.239951  0.016813  0.012165  0.028868
# NUM   0.013072  0.016934  0.035056  0.118835  0.002674  0.033571  0.211824
# PRON  0.004981  0.484291  0.023372  0.040613  0.034100  0.072031  0.092720
# DET   0.000481  0.040394  0.009618  0.017913  0.012623  0.204977  0.045323
#
#            PRT      NOUN       NUM      PRON       DET
# CONJ  0.003709  0.350487  0.042188  0.058414  0.118683
# VERB  0.031427  0.111386  0.022448  0.035916  0.133292
# ADP   0.001484  0.321213  0.061910  0.069119  0.323969
# .     0.002511  0.222531  0.081353  0.065208  0.173558
# ADV   0.014314  0.031624  0.031624  0.015646  0.069907
# ADJ   0.010156  0.700901  0.020803  0.000491  0.004914
# X     0.184891  0.062371  0.002857  0.055705  0.055229
# PRT   0.001969  0.245735  0.056102  0.017717  0.101050
# NOUN  0.043357  0.264280  0.009550  0.004721  0.013363
# NUM   0.026144  0.352347  0.184195  0.001485  0.003862
# PRON  0.012261  0.211494  0.007280  0.007663  0.009195
# DET   0.000240  0.637293  0.021640  0.003727  0.005771

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
#Vanilla Viterbi
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# ### Evaluate Vailla

# %%
#To get accuracy matrix
accuracy_matrix={}

# %%
#To get test tagged words
test_tagged_words = [tup for sent in test_set for tup in sent]
test_words = [tup[0] for sent in test_set for tup in sent]
test_words[0:10]
# Out:
# ['Investors',
#  'took',
#  'advantage',
#  'of',
#  'Tuesday',
#  "'s",
#  'stock',
#  'rally',
#  '*-1',
#  'to']

# %%
# tagging the test sentences
start = time.time()
tagged_seq = Viterbi(test_words)
print("Time taken in seconds: ", time.time()-start)
# Out:
# Time taken in seconds:  629.9195320606232

# %%
# accuracy
check = [i for i, j in zip(tagged_seq, test_tagged_words) if i == j] 
accuracy = len(check)/len(tagged_seq)
accuracy_matrix['Vanilla'] = accuracy
accuracy
# Out:
# 0.9033213454622382

# %%
#To identify incorrect tagging by Vanilla Viterbi
incorrect_tags = [[j,i[1]] for i, j in zip(tagged_seq, test_tagged_words) if i != j] 
incorrect_tags
# Out:
# [[('book', 'VERB'), 'NOUN'],
#  [('stocks', 'ADV'), 'NOUN'],
#  [('up', 'ADP'), 'PRT'],
#  [('over', 'PRT'), 'ADP'],
#  [('ignored', 'VERB'), 'CONJ'],
#  [('mine', 'ADJ'), 'NOUN'],
#  [('Palestinian', 'NOUN'), 'ADJ'],
#  [('first', 'ADV'), 'ADJ'],
#  [('Preston', 'NOUN'), 'CONJ'],
#  [('Birmingham', 'NOUN'), 'CONJ'],
#  [('Ala', 'NOUN'), 'CONJ'],
#  [('clamped', 'VERB'), 'CONJ'],
#  [('ankle', 'NOUN'), 'CONJ'],
#  [('third-largest', 'ADJ'), 'CONJ'],
#  [('fifth-largest', 'ADJ'), 'CONJ'],
#  [('Z.', 'NOUN'), 'CONJ'],
#  [('Wick', 'NOUN'), 'CONJ'],
#  [('89.7', 'NUM'), 'CONJ'],
#  [('141.9', 'NUM'), 'CONJ'],
#  [('94.8', 'NUM'), 'CONJ'],
#  [('149.9', 'NUM'), 'CONJ'],
#  [('argues', 'VERB'), 'CONJ'],
#  [('Sit', 'VERB'), 'CONJ'],
#  [('British', 'NOUN'), 'ADJ'],
#  [('halt', 'VERB'), 'NOUN'],
#  [('slides', 'VERB'), 'NOUN'],
#  [('most', 'ADV'), 'ADJ'],
#  [('athletic', 'ADJ'), 'CONJ'],
#  [('to', 'ADJ'), 'PRT'],
#  [('better', 'ADV'), 'ADJ'],
#  [('illustrates', 'VERB'), 'CONJ'],
#  [('attempt', 'NOUN'), 'VERB'],
#  [('usurp', 'VERB'), 'CONJ'],
#  [('609', 'NUM'), 'CONJ'],
#  [('executive-office', 'NOUN'), 'CONJ'],
#  [('administer', 'VERB'), 'CONJ'],
#  [('disapproved', 'VERB'), 'CONJ'],
#  [('*-58', 'X'), 'CONJ'],
#  [('disapproval', 'NOUN'), 'CONJ'],
#  [('accordance', 'NOUN'), 'CONJ'],
#  [('applicable', 'ADJ'), 'CONJ'],
#  [('Mead', 'NOUN'), 'CONJ'],
#  [('Paper', 'NOUN'), 'CONJ'],
#  [('Paper', 'NOUN'), 'CONJ'],
#  [('Paper', 'NOUN'), 'CONJ'],
#  [('Louisiana-Pacific', 'NOUN'), 'CONJ'],
#  [('Five', 'NUM'), 'CONJ'],
#  [('DeFazio', 'NOUN'), 'CONJ'],
#  [('criteria', 'NOUN'), 'CONJ'],
#  [('Proper', 'ADJ'), 'CONJ'],
#  [('rounds', 'NOUN'), 'CONJ'],
#  [('highest-pitched', 'ADJ'), 'CONJ'],
#  [('descending', 'VERB'), 'CONJ'],
#  [('as', 'ADV'), 'ADP'],
#  [('62-year-old', 'ADJ'), 'CONJ'],
#  [('executive', 'ADJ'), 'NOUN'],
#  [('forest-product', 'NOUN'), 'CONJ'],
#  [('unsolicited', 'ADJ'), 'CONJ'],
#  [('3.19', 'NUM'), 'CONJ'],
#  [('bid', 'NOUN'), 'VERB'],
#  [('that', 'DET'), 'ADP'],
#  [('diversified', 'VERB'), 'ADJ'],
#  [('that', 'DET'), 'ADP'],
#  [('impressive', 'ADJ'), 'CONJ'],
#  [('issue', 'VERB'), 'NOUN'],
#  [('29year', 'ADJ'), 'CONJ'],
#  [('nine-month', 'ADJ'), 'CONJ'],
#  [('that', 'DET'), 'ADP'],
#  [('ECONOMIC', 'ADJ'), 'CONJ'],
#  [('GROWTH', 'NOUN'), 'CONJ'],
#  [('APPEARS', 'VERB'), 'CONJ'],
#  [('off', 'ADP'), 'PRT'],
#  [('that', 'DET'), 'ADP'],
#  [('S.A', 'NOUN'), 'CONJ'],
#  [('U.S.-Japanese', 'ADJ'), 'CONJ'],
#  [('behemoth', 'NOUN'), 'CONJ'],
#  [('*T*-174', 'X'), 'CONJ'],
#  [('hotels', 'NOUN'), 'CONJ'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-175', 'X'), 'CONJ'],
#  [('masters', 'NOUN'), 'CONJ'],
#  [('Tiny', 'NOUN'), 'CONJ'],
#  [('Tots', 'NOUN'), 'CONJ'],
#  [('up', 'ADP'), 'ADV'],
#  [('past', 'NOUN'), 'ADJ'],
#  [('Kelli', 'NOUN'), 'CONJ'],
#  [('Green', 'NOUN'), 'CONJ'],
#  [('senior', 'NOUN'), 'ADJ'],
#  [('speculate', 'VERB'), 'CONJ'],
#  [('yen-support', 'ADJ'), 'CONJ'],
#  [('intervention', 'NOUN'), 'CONJ'],
#  [('150.00', 'NUM'), 'CONJ'],
#  [('excess', 'NOUN'), 'ADJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('up', 'PRT'), 'ADV'],
#  [('smiles', 'NOUN'), 'CONJ'],
#  [('Mont', 'NOUN'), 'CONJ'],
#  [('exits', 'NOUN'), 'CONJ'],
#  [('rebound', 'NOUN'), 'VERB'],
#  [('pushes', 'VERB'), 'CONJ'],
#  [('Left', 'VERB'), 'CONJ'],
#  [('more', 'ADV'), 'ADJ'],
#  [('so', 'ADV'), 'ADP'],
#  [('much', 'ADV'), 'ADJ'],
#  [('Sandoz', 'NOUN'), 'CONJ'],
#  [('preclinical', 'ADJ'), 'CONJ'],
#  [('vague', 'ADJ'), 'CONJ'],
#  [('mushy', 'ADJ'), 'CONJ'],
#  [('that', 'ADP'), 'DET'],
#  [('viewpoints', 'NOUN'), 'CONJ'],
#  [('out', 'ADV'), 'PRT'],
#  [('le', 'DET'), 'CONJ'],
#  [('115', 'NUM'), 'CONJ'],
#  [('genie', 'NOUN'), 'CONJ'],
#  [('len', 'NOUN'), 'CONJ'],
#  [("'s", 'PRT'), 'VERB'],
#  [('foldability', 'NOUN'), 'CONJ'],
#  [('inserted', 'VERB'), 'CONJ'],
#  [('incisions', 'NOUN'), 'CONJ'],
#  [('eye', 'NOUN'), 'CONJ'],
#  [('care', 'NOUN'), 'VERB'],
#  [('care', 'NOUN'), 'VERB'],
#  [('clear', 'VERB'), 'ADJ'],
#  [('ethanol', 'NOUN'), 'CONJ'],
#  [('fuel', 'VERB'), 'NOUN'],
#  [('fleet', 'NOUN'), 'CONJ'],
#  [('Lucille', 'NOUN'), 'CONJ'],
#  [('84-year-old', 'ADJ'), 'CONJ'],
#  [('housewife', 'NOUN'), 'CONJ'],
#  [('amazingly', 'ADV'), 'CONJ'],
#  [('jolts', 'NOUN'), 'CONJ'],
#  [('DISCOUNT', 'NOUN'), 'CONJ'],
#  [('sight', 'NOUN'), 'CONJ'],
#  [('*T*-178', 'X'), 'CONJ'],
#  [('Kirkpatrick', 'NOUN'), 'CONJ'],
#  [('*-154', 'X'), 'CONJ'],
#  [('Sumitomo', 'NOUN'), 'CONJ'],
#  [('Metal', 'NOUN'), 'CONJ'],
#  [('692', 'NUM'), 'CONJ'],
#  [('960', 'NUM'), 'CONJ'],
#  [('individual', 'NOUN'), 'ADJ'],
#  [('51.6', 'NUM'), 'CONJ'],
#  [('readings', 'NOUN'), 'CONJ'],
#  [('wrestling', 'VERB'), 'CONJ'],
#  [('intelligent', 'ADJ'), 'CONJ'],
#  [('insane', 'ADJ'), 'CONJ'],
#  [('that', 'DET'), 'ADP'],
#  [('tailor-made', 'ADJ'), 'CONJ'],
#  [('more', 'ADJ'), 'ADV'],
#  [('purhasing', 'NOUN'), 'CONJ'],
#  [('report', 'NOUN'), 'VERB'],
#  [('movies', 'NOUN'), 'CONJ'],
#  [('Peck', 'NOUN'), 'CONJ'],
#  [('marvelously', 'ADV'), 'CONJ'],
#  [('loose', 'ADJ'), 'CONJ'],
#  [('portrayal', 'NOUN'), 'CONJ'],
#  [('work', 'NOUN'), 'VERB'],
#  [('force', 'NOUN'), 'VERB'],
#  [('Cataracts', 'NOUN'), 'CONJ'],
#  [('refer', 'VERB'), 'CONJ'],
#  [('clouding', 'NOUN'), 'CONJ'],
#  [('eye', 'NOUN'), 'CONJ'],
#  [("'s", 'PRT'), 'VERB'],
#  [('*-107', 'X'), 'CONJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('maturing', 'VERB'), 'CONJ'],
#  [('up', 'PRT'), 'ADV'],
#  [('filled', 'VERB'), 'CONJ'],
#  [('solemn', 'ADJ'), 'CONJ'],
#  [('intoxication', 'NOUN'), 'CONJ'],
#  [('*T*-226', 'X'), 'CONJ'],
#  [('intricate', 'ADJ'), 'CONJ'],
#  [('ritual', 'NOUN'), 'CONJ'],
#  [('faultlessly', 'ADV'), 'CONJ'],
#  [('properties', 'NOUN'), 'CONJ'],
#  [('Indexing', 'NOUN'), 'CONJ'],
#  [('barometer', 'NOUN'), 'CONJ'],
#  [('panic', 'VERB'), 'NOUN'],
#  [('so', 'ADP'), 'ADV'],
#  [('crying', 'VERB'), 'CONJ'],
#  [('assistant', 'ADJ'), 'NOUN'],
#  [('Ilminster', 'NOUN'), 'CONJ'],
#  [('Somerset', 'NOUN'), 'CONJ'],
#  [('following', 'VERB'), 'NOUN'],
#  [('dust-up', 'NOUN'), 'CONJ'],
#  [('attendance', 'NOUN'), 'CONJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('8.75', 'NUM'), 'CONJ'],
#  [('shown', 'VERB'), 'CONJ'],
#  [('Video', 'NOUN'), 'CONJ'],
#  [('Tip', 'NOUN'), 'CONJ'],
#  [('finest', 'ADJ'), 'CONJ'],
#  [('472', 'NUM'), 'CONJ'],
#  [('defeats', 'VERB'), 'CONJ'],
#  [('inkling', 'NOUN'), 'CONJ'],
#  [('that', 'ADP'), 'DET'],
#  [('underprivileged', 'ADJ'), 'CONJ'],
#  [('prosecutor', 'NOUN'), 'CONJ'],
#  [('*T*-96', 'X'), 'CONJ'],
#  [('alumni', 'NOUN'), 'CONJ'],
#  [('cultivated', 'VERB'), 'CONJ'],
#  [('much', 'ADV'), 'ADJ'],
#  [('savvier', 'ADJ'), 'CONJ'],
#  [('much', 'ADJ'), 'ADV'],
#  [('burned', 'VERB'), 'CONJ'],
#  [('wrath', 'NOUN'), 'CONJ'],
#  [('Californian', 'NOUN'), 'CONJ'],
#  [('Bolivia', 'NOUN'), 'CONJ'],
#  [('broadened', 'VERB'), 'CONJ'],
#  [('initiate', 'NOUN'), 'CONJ'],
#  [('as', 'ADV'), 'ADP'],
#  [('R.D.', 'NOUN'), 'CONJ'],
#  [('Vos', 'NOUN'), 'CONJ'],
#  [('N.Y', 'NOUN'), 'CONJ'],
#  [('delayed', 'VERB'), 'CONJ'],
#  [('as', 'ADV'), 'ADP'],
#  [('Above', 'ADP'), 'CONJ'],
#  [('confused', 'VERB'), 'ADJ'],
#  [('around', 'PRT'), 'ADP'],
#  [('accountants', 'NOUN'), 'CONJ'],
#  [('blinks', 'VERB'), 'CONJ'],
#  [('eye', 'NOUN'), 'CONJ'],
#  [('bar', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('abortion-related', 'ADJ'), 'CONJ'],
#  [("'s", 'VERB'), 'PRT'],
#  [('more', 'ADV'), 'ADJ'],
#  [('further', 'ADV'), 'ADJ'],
#  [('load', 'VERB'), 'NOUN'],
#  [('dreamed', 'VERB'), 'CONJ'],
#  [('up', 'PRT'), 'ADV'],
#  [('improbable', 'ADJ'), 'CONJ'],
#  [('shop', 'NOUN'), 'CONJ'],
#  [('high-rise', 'ADJ'), 'CONJ'],
#  [('help', 'NOUN'), 'VERB'],
#  [('diagram', 'NOUN'), 'CONJ'],
#  [('arrows', 'NOUN'), 'CONJ'],
#  [('polystyrene', 'NOUN'), 'CONJ'],
#  [('foam', 'NOUN'), 'CONJ'],
#  [('polyproplene', 'NOUN'), 'CONJ'],
#  [('polyester', 'NOUN'), 'CONJ'],
#  [('plastic', 'NOUN'), 'ADJ'],
#  [('non-biodegradable', 'ADJ'), 'CONJ'],
#  [('over', 'PRT'), 'ADP'],
#  [('seventh', 'ADJ'), 'CONJ'],
#  [("'82", 'NUM'), 'CONJ'],
#  [('115', 'NUM'), 'CONJ'],
#  [('Researchers', 'NOUN'), 'CONJ'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('closer', 'ADJ'), 'ADV'],
#  [('unwilling', 'ADJ'), 'CONJ'],
#  [('manpower', 'NOUN'), 'CONJ'],
#  [('removing', 'VERB'), 'CONJ'],
#  [('safeguarding', 'VERB'), 'CONJ'],
#  [('Anku', 'NOUN'), 'CONJ'],
#  [('Ketchum', 'NOUN'), 'CONJ'],
#  [('Braun', 'NOUN'), 'CONJ'],
#  [('investor-relations', 'NOUN'), 'CONJ'],
#  [('marketing-communications', 'NOUN'), 'CONJ'],
#  [('headed', 'VERB'), 'CONJ'],
#  [('curbed', 'VERB'), 'CONJ'],
#  [('index-fund', 'ADJ'), 'NOUN'],
#  [('leveraging', 'VERB'), 'CONJ'],
#  [('owning', 'VERB'), 'CONJ'],
#  [('own', 'VERB'), 'ADJ'],
#  [('flirted', 'VERB'), 'CONJ'],
#  [('charge', 'VERB'), 'NOUN'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('matters', 'VERB'), 'NOUN'],
#  [('fine', 'ADV'), 'NOUN'],
#  [('chief', 'ADJ'), 'NOUN'],
#  [('*-152', 'X'), 'CONJ'],
#  [('father-in-law', 'NOUN'), 'CONJ'],
#  [('Gardner', 'NOUN'), 'CONJ'],
#  [('Hubbard', 'NOUN'), 'CONJ'],
#  [('wealthy', 'ADJ'), 'CONJ'],
#  [('well-connected', 'ADJ'), 'CONJ'],
#  [('financing', 'NOUN'), 'VERB'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('Moon', 'NOUN'), 'CONJ'],
#  [('Landrieu', 'NOUN'), 'CONJ'],
#  [('that', 'DET'), 'ADP'],
#  [('cavernous', 'ADJ'), 'CONJ'],
#  [('money-losing', 'ADJ'), 'CONJ'],
#  [('benefits', 'VERB'), 'NOUN'],
#  [('relevance', 'NOUN'), 'CONJ'],
#  [('U.S.', 'ADJ'), 'NOUN'],
#  [('143.93', 'NUM'), 'CONJ'],
#  [('close', 'NOUN'), 'VERB'],
#  [('143.08', 'NUM'), 'CONJ'],
#  [('appeal', 'VERB'), 'NOUN'],
#  [('cleanup', 'NOUN'), 'CONJ'],
#  [('burn', 'VERB'), 'CONJ'],
#  [('cleaner-burning', 'ADJ'), 'CONJ'],
#  [('fuels', 'NOUN'), 'CONJ'],
#  [('858,000', 'NUM'), 'CONJ'],
#  [('overvalued', 'VERB'), 'CONJ'],
#  [('Paris', 'NOUN'), 'CONJ'],
#  [('Brussels', 'NOUN'), 'CONJ'],
#  [('Milan', 'NOUN'), 'CONJ'],
#  [('that', 'DET'), 'ADP'],
#  [('discretion', 'NOUN'), 'CONJ'],
#  [('select', 'VERB'), 'CONJ'],
#  [('net', 'NOUN'), 'ADJ'],
#  [('306', 'NUM'), 'CONJ'],
#  [('unrestricted', 'ADJ'), 'CONJ'],
#  [('that', 'DET'), 'ADP'],
#  [('*-165', 'X'), 'CONJ'],
#  [('firm', 'ADJ'), 'NOUN'],
#  [('opening', 'NOUN'), 'VERB'],
#  [('tempted', 'VERB'), 'CONJ'],
#  [('less', 'ADJ'), 'ADV'],
#  [('higher', 'ADV'), 'ADJ'],
#  [('trading', 'VERB'), 'NOUN'],
#  [('1980s', 'NOUN'), 'NUM'],
#  [('glory', 'NOUN'), 'CONJ'],
#  [('faded', 'VERB'), 'CONJ'],
#  [('yellow', 'ADJ'), 'CONJ'],
#  [('bricks', 'NOUN'), 'CONJ'],
#  [('facade', 'NOUN'), 'CONJ'],
#  [('record', 'ADJ'), 'NOUN'],
#  [('550,000', 'NUM'), 'CONJ'],
#  [('Four', 'NUM'), 'CONJ'],
#  [('diagnosed', 'VERB'), 'CONJ'],
#  [('half', 'NOUN'), 'DET'],
#  [('27-year', 'ADJ'), 'CONJ'],
#  [('information-services', 'NOUN'), 'CONJ'],
#  [('Southeast', 'ADJ'), 'NOUN'],
#  [('1997', 'NUM'), 'CONJ'],
#  [('uses', 'NOUN'), 'VERB'],
#  [('cancer-causing', 'ADJ'), 'CONJ'],
#  [('outlawed', 'VERB'), 'CONJ'],
#  [('stemmed', 'VERB'), 'CONJ'],
#  [('post', 'NOUN'), 'VERB'],
#  [('directorship', 'NOUN'), 'CONJ'],
#  [('little', 'ADV'), 'ADJ'],
#  [('more', 'ADV'), 'ADJ'],
#  [('what', 'DET'), 'PRON'],
#  [('that', 'DET'), 'ADP'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-117', 'X'), 'CONJ'],
#  [('uptick', 'VERB'), 'NOUN'],
#  [('head', 'ADJ'), 'NOUN'],
#  [('Silverman', 'NOUN'), 'CONJ'],
#  [('insurance-company', 'NOUN'), 'CONJ'],
#  [('comments', 'VERB'), 'NOUN'],
#  [('increases', 'VERB'), 'NOUN'],
#  [('jeopardy', 'NOUN'), 'CONJ'],
#  [('NEW', 'NOUN'), 'CONJ'],
#  [('ACCOUNT', 'NOUN'), 'CONJ'],
#  [('14.75', 'NUM'), 'CONJ'],
#  [('Chilver', 'NOUN'), 'CONJ'],
#  [('63-year-old', 'ADJ'), 'CONJ'],
#  [('English', 'NOUN'), 'ADJ'],
#  [('Clays', 'NOUN'), 'CONJ'],
#  [('CoreStates', 'NOUN'), 'CONJ'],
#  [('Earle', 'NOUN'), 'CONJ'],
#  [('Palmer', 'NOUN'), 'CONJ'],
#  [('Spiro', 'NOUN'), 'CONJ'],
#  [('account', 'NOUN'), 'VERB'],
#  [('there', 'ADV'), 'DET'],
#  [('what', 'DET'), 'PRON'],
#  [('escape', 'NOUN'), 'CONJ'],
#  [('open', 'ADJ'), 'VERB'],
#  [('drink', 'NOUN'), 'VERB'],
#  [('insanity', 'NOUN'), 'CONJ'],
#  [('heirs', 'NOUN'), 'CONJ'],
#  [('Nylev', 'NOUN'), 'CONJ'],
#  [('Municipal', 'NOUN'), 'ADJ'],
#  [('up', 'ADP'), 'ADV'],
#  [('malnutrition', 'NOUN'), 'CONJ'],
#  [('chest', 'NOUN'), 'CONJ'],
#  [('cardiovascular', 'ADJ'), 'CONJ'],
#  [('infectious', 'ADJ'), 'CONJ'],
#  [('aftereffects', 'NOUN'), 'CONJ'],
#  [('assaults', 'NOUN'), 'CONJ'],
#  [('*T*-91', 'X'), 'CONJ'],
#  [('grandstander', 'NOUN'), 'CONJ'],
#  [('luxury', 'NOUN'), 'CONJ'],
#  [('879', 'NUM'), 'CONJ'],
#  [('13.90', 'NUM'), 'CONJ'],
#  [('guarantee', 'NOUN'), 'VERB'],
#  [('operating', 'VERB'), 'NOUN'],
#  [('shopped', 'VERB'), 'CONJ'],
#  [('that', 'DET'), 'ADP'],
#  [('half', 'NOUN'), 'DET'],
#  [('espouse', 'VERB'), 'CONJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('one-third', 'ADJ'), 'NOUN'],
#  [('finance', 'NOUN'), 'VERB'],
#  [('deteriorating', 'VERB'), 'CONJ'],
#  [('Anderson', 'NOUN'), 'CONJ'],
#  [('59-year-old', 'ADJ'), 'CONJ'],
#  [('fluctuations', 'NOUN'), 'CONJ'],
#  [('heebie-jeebies', 'NOUN'), 'CONJ'],
#  [('much', 'ADJ'), 'ADV'],
#  [('point', 'NOUN'), 'VERB'],
#  [('outlawing', 'VERB'), 'CONJ'],
#  [('audit', 'NOUN'), 'VERB'],
#  [('stand', 'NOUN'), 'VERB'],
#  [('display', 'VERB'), 'CONJ'],
#  [('projector', 'NOUN'), 'CONJ'],
#  [('underline', 'VERB'), 'CONJ'],
#  [('Old-House', 'NOUN'), 'CONJ'],
#  [('publishing', 'NOUN'), 'VERB'],
#  [('126,000', 'NUM'), 'CONJ'],
#  [('all', 'ADV'), 'DET'],
#  [('following', 'NOUN'), 'VERB'],
#  [('round-trip', 'ADJ'), 'CONJ'],
#  [('Trans', 'NOUN'), 'CONJ'],
#  [('luxury', 'NOUN'), 'CONJ'],
#  [('soaring', 'VERB'), 'CONJ'],
#  [('reclaimed', 'VERB'), 'CONJ'],
#  [('240-page', 'ADJ'), 'CONJ'],
#  [('Iran-Contra', 'NOUN'), 'CONJ'],
#  [('221.4', 'NUM'), 'CONJ'],
#  [('Next', 'ADJ'), 'CONJ'],
#  [('Philippine', 'NOUN'), 'CONJ'],
#  [('launch', 'NOUN'), 'VERB'],
#  [('capped', 'VERB'), 'ADJ'],
#  [('Philippine', 'ADJ'), 'CONJ'],
#  [('Corazon', 'NOUN'), 'CONJ'],
#  [('Aquino', 'NOUN'), 'CONJ'],
#  [('the', 'NOUN'), 'DET'],
#  [('midyear', 'NOUN'), 'CONJ'],
#  [('Spending', 'NOUN'), 'CONJ'],
#  [('nonresidential', 'ADJ'), 'CONJ'],
#  [('off', 'ADJ'), 'PRT'],
#  [('99.1', 'NUM'), 'CONJ'],
#  [('awaits', 'VERB'), 'CONJ'],
#  [('point', 'VERB'), 'NOUN'],
#  [('Aerospace', 'NOUN'), 'CONJ'],
#  [('sagged', 'VERB'), 'CONJ'],
#  [('B-1B', 'NOUN'), 'ADJ'],
#  [('bombers', 'NOUN'), 'CONJ'],
#  [('out', 'ADP'), 'PRT'],
#  [('half', 'DET'), 'NOUN'],
#  [('88.32', 'NUM'), 'CONJ'],
#  [('618.1', 'NUM'), 'CONJ'],
#  [('77.6', 'NUM'), 'CONJ'],
#  [('earlier', 'ADJ'), 'ADV'],
#  [('12.52', 'NUM'), 'CONJ'],
#  [('11.95', 'NUM'), 'CONJ'],
#  [('shipboard', 'NOUN'), 'CONJ'],
#  [('next', 'ADJ'), 'ADP'],
#  [('Soviet', 'NOUN'), 'ADJ'],
#  [('off', 'ADP'), 'PRT'],
#  [('Malta', 'NOUN'), 'CONJ'],
#  [('NCNB', 'NOUN'), 'CONJ'],
#  [('Connections', 'NOUN'), 'CONJ'],
#  [('adults', 'NOUN'), 'CONJ'],
#  [('broadly', 'ADV'), 'CONJ'],
#  [('construed', 'VERB'), 'CONJ'],
#  [('emasculate', 'VERB'), 'CONJ'],
#  [('swallow', 'VERB'), 'CONJ'],
#  [('contrary', 'ADJ'), 'NOUN'],
#  [('the', 'NUM'), 'DET']]

# %% [markdown]
# # Common Issues
# 1. Numbers are defined as Det
# 2. Nouns are defines as Det.
# 3. Verts are defined as Det.
# 4. other are defied as Det.
# 5. Verbs are defined as Noun.
#
# Most of the incorrect POS  are Determinent.

# %% [markdown]
# ### Solve the problem of unknown words.

# %% [markdown]
# ###  1. Most Frequent Tag

# %% [markdown]
# As per the logic viterbi algorithm assigns the first tag from the tag list for unknown words.
#
# As determenent is first in the list. all unknown words are assigned as determinent.
#
# Hence, using the sorted list. (As per frequency) to that most frequent comes in the list and all unknown words are assigned as Noun

# %%
def sorted_tags(train_bag = train_tagged_words):
    T = list(set([pair[1] for pair in train_bag]))
    tag_freq={}
    for  tag in tags:
        tag_freq[tag] =  len([pair for pair in train_bag if pair[1]==tag])
    tag_freq = pd.DataFrame(tag_freq.items(),columns=['tag','freq'])
    return list(tag_freq.sort_values(by='freq',ascending=False).tag)

# %%
#Most common tag
sorted_tags()[0]
# Out:
# 'NOUN'

# %%
#Viterbi -  Most common tag
def Viterbi_frequent(words, train_bag = train_tagged_words):
    state = []
    T = sorted_tags()
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluate Most Frequent Tag

# %%
# tagging the test sentences
start = time.time()
tagged_seq_frequent = Viterbi_frequent(test_words)
print("Time taken in seconds: ", time.time()-start)
# Out:
# Time taken in seconds:  687.4354703426361

# %%
# accuracy
check = [i for i, j in zip(tagged_seq_frequent, test_tagged_words) if i == j] 
accuracy = len(check)/len(tagged_seq_frequent)
accuracy_matrix['Most Frequent POS'] = accuracy
accuracy
# Out:
# 0.9348423947535435

# %%
#To identify incorrect tagging by Viterbi  - most frequent words
incorrect_tags = [[j,i[1]] for i, j in zip(tagged_seq_frequent, test_tagged_words) if i != j]

# %%
incorrect_tags
# Out:
# [[('book', 'VERB'), 'NOUN'],
#  [('stocks', 'ADV'), 'NOUN'],
#  [('up', 'ADP'), 'PRT'],
#  [('over', 'PRT'), 'ADP'],
#  [('ignored', 'VERB'), 'NOUN'],
#  [('mine', 'ADJ'), 'NOUN'],
#  [('Palestinian', 'NOUN'), 'ADJ'],
#  [('first', 'ADV'), 'ADJ'],
#  [('clamped', 'VERB'), 'NOUN'],
#  [('third-largest', 'ADJ'), 'NOUN'],
#  [('fifth-largest', 'ADJ'), 'NOUN'],
#  [('89.7', 'NUM'), 'NOUN'],
#  [('141.9', 'NUM'), 'NOUN'],
#  [('94.8', 'NUM'), 'NOUN'],
#  [('149.9', 'NUM'), 'NOUN'],
#  [('argues', 'VERB'), 'NOUN'],
#  [('Sit', 'VERB'), 'NOUN'],
#  [('down', 'ADV'), 'ADP'],
#  [('British', 'NOUN'), 'ADJ'],
#  [('halt', 'VERB'), 'NOUN'],
#  [('slides', 'VERB'), 'NOUN'],
#  [('most', 'ADV'), 'ADJ'],
#  [('athletic', 'ADJ'), 'NOUN'],
#  [('to', 'ADJ'), 'PRT'],
#  [('better', 'ADV'), 'ADJ'],
#  [('illustrates', 'VERB'), 'NOUN'],
#  [('attempt', 'NOUN'), 'VERB'],
#  [('usurp', 'VERB'), 'NOUN'],
#  [('executive', 'ADJ'), 'NOUN'],
#  [('609', 'NUM'), 'NOUN'],
#  [('administer', 'VERB'), 'NOUN'],
#  [('disapproved', 'VERB'), 'NOUN'],
#  [('*-58', 'X'), 'NOUN'],
#  [('applicable', 'ADJ'), 'NOUN'],
#  [('Five', 'NUM'), 'NOUN'],
#  [('Proper', 'ADJ'), 'NOUN'],
#  [('English', 'ADJ'), 'NOUN'],
#  [('highest-pitched', 'ADJ'), 'NOUN'],
#  [('descending', 'VERB'), 'NOUN'],
#  [('as', 'ADV'), 'ADP'],
#  [('62-year-old', 'ADJ'), 'NOUN'],
#  [('executive', 'ADJ'), 'NOUN'],
#  [('unsolicited', 'ADJ'), 'NOUN'],
#  [('3.19', 'NUM'), 'NOUN'],
#  [('bid', 'NOUN'), 'VERB'],
#  [('that', 'DET'), 'ADP'],
#  [('diversified', 'VERB'), 'ADJ'],
#  [('that', 'DET'), 'ADP'],
#  [('impressive', 'ADJ'), 'NOUN'],
#  [('issue', 'VERB'), 'NOUN'],
#  [('29year', 'ADJ'), 'NOUN'],
#  [('nine-month', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('ECONOMIC', 'ADJ'), 'NOUN'],
#  [('APPEARS', 'VERB'), 'NOUN'],
#  [('off', 'ADP'), 'PRT'],
#  [('that', 'DET'), 'ADP'],
#  [('U.S.-Japanese', 'ADJ'), 'NOUN'],
#  [('*T*-174', 'X'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-175', 'X'), 'NOUN'],
#  [('up', 'ADP'), 'ADV'],
#  [('past', 'NOUN'), 'ADJ'],
#  [('senior', 'NOUN'), 'ADJ'],
#  [('speculate', 'VERB'), 'NOUN'],
#  [('yen-support', 'ADJ'), 'NOUN'],
#  [('150.00', 'NUM'), 'NOUN'],
#  [('excess', 'NOUN'), 'ADJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('up', 'PRT'), 'ADV'],
#  [('rebound', 'NOUN'), 'VERB'],
#  [('pushes', 'VERB'), 'NOUN'],
#  [('Left', 'VERB'), 'NOUN'],
#  [('more', 'ADV'), 'ADJ'],
#  [('so', 'ADV'), 'ADP'],
#  [('much', 'ADV'), 'ADJ'],
#  [('preclinical', 'ADJ'), 'NOUN'],
#  [('vague', 'ADJ'), 'NOUN'],
#  [('mushy', 'ADJ'), 'NOUN'],
#  [('that', 'ADP'), 'DET'],
#  [('out', 'ADV'), 'PRT'],
#  [('le', 'DET'), 'NOUN'],
#  [('115', 'NUM'), 'NOUN'],
#  [('back', 'ADV'), 'PRT'],
#  [('inserted', 'VERB'), 'NOUN'],
#  [('care', 'NOUN'), 'VERB'],
#  [('care', 'NOUN'), 'VERB'],
#  [('clear', 'VERB'), 'ADJ'],
#  [('fuel', 'VERB'), 'NOUN'],
#  [('84-year-old', 'ADJ'), 'NOUN'],
#  [('amazingly', 'ADV'), 'NOUN'],
#  [('*T*-178', 'X'), 'NOUN'],
#  [('*-154', 'X'), 'NOUN'],
#  [('692', 'NUM'), 'NOUN'],
#  [('960', 'NUM'), 'NOUN'],
#  [('individual', 'NOUN'), 'ADJ'],
#  [('51.6', 'NUM'), 'NOUN'],
#  [('wrestling', 'VERB'), 'NOUN'],
#  [('intelligent', 'ADJ'), 'NOUN'],
#  [('insane', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('tailor-made', 'ADJ'), 'NOUN'],
#  [('more', 'ADJ'), 'ADV'],
#  [('report', 'NOUN'), 'VERB'],
#  [('marvelously', 'ADV'), 'NOUN'],
#  [('loose', 'ADJ'), 'NOUN'],
#  [('work', 'NOUN'), 'VERB'],
#  [('force', 'NOUN'), 'VERB'],
#  [('refer', 'VERB'), 'NOUN'],
#  [('*-107', 'X'), 'NOUN'],
#  [('next', 'ADJ'), 'ADP'],
#  [('about', 'ADV'), 'ADP'],
#  [('maturing', 'VERB'), 'NOUN'],
#  [('up', 'PRT'), 'ADV'],
#  [('filled', 'VERB'), 'NOUN'],
#  [('solemn', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-226', 'X'), 'NOUN'],
#  [('intricate', 'ADJ'), 'NOUN'],
#  [('faultlessly', 'ADV'), 'NOUN'],
#  [('panic', 'VERB'), 'NOUN'],
#  [('so', 'ADP'), 'ADV'],
#  [('crying', 'VERB'), 'NOUN'],
#  [('assistant', 'ADJ'), 'NOUN'],
#  [('following', 'VERB'), 'NOUN'],
#  [('about', 'ADV'), 'ADP'],
#  [('8.75', 'NUM'), 'NOUN'],
#  [('shown', 'VERB'), 'NOUN'],
#  [('finest', 'ADJ'), 'NOUN'],
#  [('472', 'NUM'), 'NOUN'],
#  [('defeats', 'VERB'), 'NOUN'],
#  [('underprivileged', 'ADJ'), 'NOUN'],
#  [('*T*-96', 'X'), 'NOUN'],
#  [('cultivated', 'VERB'), 'NOUN'],
#  [('much', 'ADV'), 'ADJ'],
#  [('savvier', 'ADJ'), 'NOUN'],
#  [('much', 'ADJ'), 'ADV'],
#  [('burned', 'VERB'), 'NOUN'],
#  [('broadened', 'VERB'), 'NOUN'],
#  [('as', 'ADV'), 'ADP'],
#  [('delayed', 'VERB'), 'NOUN'],
#  [('as', 'ADV'), 'ADP'],
#  [('Above', 'ADP'), 'NOUN'],
#  [('confused', 'VERB'), 'ADJ'],
#  [('around', 'PRT'), 'ADP'],
#  [('blinks', 'VERB'), 'NOUN'],
#  [('bar', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('abortion-related', 'ADJ'), 'NOUN'],
#  [("'s", 'VERB'), 'PRT'],
#  [('more', 'ADV'), 'ADJ'],
#  [('further', 'ADV'), 'ADJ'],
#  [('load', 'VERB'), 'NOUN'],
#  [('dreamed', 'VERB'), 'NOUN'],
#  [('improbable', 'ADJ'), 'NOUN'],
#  [('high-rise', 'ADJ'), 'NOUN'],
#  [('help', 'NOUN'), 'VERB'],
#  [('plastic', 'NOUN'), 'ADJ'],
#  [('non-biodegradable', 'ADJ'), 'NOUN'],
#  [('over', 'PRT'), 'ADP'],
#  [('seventh', 'ADJ'), 'NOUN'],
#  [("'82", 'NUM'), 'NOUN'],
#  [('115', 'NUM'), 'NOUN'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('closer', 'ADJ'), 'ADV'],
#  [('unwilling', 'ADJ'), 'NOUN'],
#  [('removing', 'VERB'), 'NOUN'],
#  [('safeguarding', 'VERB'), 'NOUN'],
#  [('headed', 'VERB'), 'NOUN'],
#  [('curbed', 'VERB'), 'NOUN'],
#  [('index-fund', 'ADJ'), 'NOUN'],
#  [('leveraging', 'VERB'), 'NOUN'],
#  [('owning', 'VERB'), 'NOUN'],
#  [('more', 'ADJ'), 'ADV'],
#  [('own', 'VERB'), 'ADJ'],
#  [('flirted', 'VERB'), 'NOUN'],
#  [('charge', 'VERB'), 'NOUN'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('matters', 'VERB'), 'NOUN'],
#  [('fine', 'ADV'), 'NOUN'],
#  [('chief', 'ADJ'), 'NOUN'],
#  [('*-152', 'X'), 'NOUN'],
#  [('wealthy', 'ADJ'), 'NOUN'],
#  [('well-connected', 'ADJ'), 'NOUN'],
#  [('financing', 'NOUN'), 'VERB'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('that', 'DET'), 'ADP'],
#  [('cavernous', 'ADJ'), 'NOUN'],
#  [('money-losing', 'ADJ'), 'NOUN'],
#  [('benefits', 'VERB'), 'NOUN'],
#  [('U.S.', 'ADJ'), 'NOUN'],
#  [('143.93', 'NUM'), 'NOUN'],
#  [('close', 'NOUN'), 'VERB'],
#  [('143.08', 'NUM'), 'NOUN'],
#  [('appeal', 'VERB'), 'NOUN'],
#  [('burn', 'VERB'), 'NOUN'],
#  [('cleaner-burning', 'ADJ'), 'NOUN'],
#  [('858,000', 'NUM'), 'NOUN'],
#  [('overvalued', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('select', 'VERB'), 'NOUN'],
#  [('net', 'NOUN'), 'ADJ'],
#  [('306', 'NUM'), 'NOUN'],
#  [('unrestricted', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('*-165', 'X'), 'NOUN'],
#  [('firm', 'ADJ'), 'NOUN'],
#  [('opening', 'NOUN'), 'VERB'],
#  [('tempted', 'VERB'), 'NOUN'],
#  [('less', 'ADJ'), 'ADV'],
#  [('higher', 'ADV'), 'ADJ'],
#  [('trading', 'VERB'), 'NOUN'],
#  [('1980s', 'NOUN'), 'NUM'],
#  [('faded', 'VERB'), 'NOUN'],
#  [('yellow', 'ADJ'), 'NOUN'],
#  [('record', 'ADJ'), 'NOUN'],
#  [('550,000', 'NUM'), 'NOUN'],
#  [('Four', 'NUM'), 'NOUN'],
#  [('diagnosed', 'VERB'), 'NOUN'],
#  [('half', 'NOUN'), 'DET'],
#  [('27-year', 'ADJ'), 'NOUN'],
#  [('Southeast', 'ADJ'), 'NOUN'],
#  [('1997', 'NUM'), 'NOUN'],
#  [('uses', 'NOUN'), 'VERB'],
#  [('cancer-causing', 'ADJ'), 'NOUN'],
#  [('outlawed', 'VERB'), 'NOUN'],
#  [('stemmed', 'VERB'), 'NOUN'],
#  [('post', 'NOUN'), 'VERB'],
#  [('little', 'ADV'), 'ADJ'],
#  [('more', 'ADV'), 'ADJ'],
#  [('what', 'DET'), 'PRON'],
#  [('that', 'DET'), 'ADP'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-117', 'X'), 'NOUN'],
#  [('uptick', 'VERB'), 'NOUN'],
#  [('head', 'ADJ'), 'NOUN'],
#  [('comments', 'VERB'), 'NOUN'],
#  [('increases', 'VERB'), 'NOUN'],
#  [('14.75', 'NUM'), 'NOUN'],
#  [('63-year-old', 'ADJ'), 'NOUN'],
#  [('English', 'NOUN'), 'ADJ'],
#  [('account', 'NOUN'), 'VERB'],
#  [('there', 'ADV'), 'DET'],
#  [('what', 'DET'), 'PRON'],
#  [('open', 'ADJ'), 'VERB'],
#  [('drink', 'NOUN'), 'VERB'],
#  [('up', 'ADP'), 'ADV'],
#  [('cardiovascular', 'ADJ'), 'NOUN'],
#  [('infectious', 'ADJ'), 'NOUN'],
#  [('*T*-91', 'X'), 'NOUN'],
#  [('879', 'NUM'), 'NOUN'],
#  [('13.90', 'NUM'), 'NOUN'],
#  [('guarantee', 'NOUN'), 'VERB'],
#  [('operating', 'VERB'), 'NOUN'],
#  [('shopped', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('half', 'NOUN'), 'DET'],
#  [('espouse', 'VERB'), 'NOUN'],
#  [('about', 'ADV'), 'ADP'],
#  [('one-third', 'ADJ'), 'NOUN'],
#  [('finance', 'NOUN'), 'VERB'],
#  [('deteriorating', 'VERB'), 'NOUN'],
#  [('59-year-old', 'ADJ'), 'NOUN'],
#  [('much', 'ADJ'), 'ADV'],
#  [('point', 'NOUN'), 'VERB'],
#  [('outlawing', 'VERB'), 'NOUN'],
#  [('audit', 'NOUN'), 'VERB'],
#  [('stand', 'NOUN'), 'VERB'],
#  [('display', 'VERB'), 'NOUN'],
#  [('underline', 'VERB'), 'NOUN'],
#  [('publishing', 'NOUN'), 'VERB'],
#  [('126,000', 'NUM'), 'NOUN'],
#  [('all', 'ADV'), 'DET'],
#  [('following', 'NOUN'), 'VERB'],
#  [('round-trip', 'ADJ'), 'NOUN'],
#  [('soaring', 'VERB'), 'NOUN'],
#  [('reclaimed', 'VERB'), 'NOUN'],
#  [('240-page', 'ADJ'), 'NOUN'],
#  [('221.4', 'NUM'), 'NOUN'],
#  [('Next', 'ADJ'), 'NOUN'],
#  [('launch', 'NOUN'), 'VERB'],
#  [('capped', 'VERB'), 'ADJ'],
#  [('Philippine', 'ADJ'), 'NOUN'],
#  [('the', 'NOUN'), 'DET'],
#  [('nonresidential', 'ADJ'), 'NOUN'],
#  [('off', 'ADJ'), 'PRT'],
#  [('99.1', 'NUM'), 'NOUN'],
#  [('awaits', 'VERB'), 'NOUN'],
#  [('point', 'VERB'), 'NOUN'],
#  [('sagged', 'VERB'), 'NOUN'],
#  [('B-1B', 'NOUN'), 'ADJ'],
#  [('out', 'ADP'), 'PRT'],
#  [('half', 'DET'), 'NOUN'],
#  [('88.32', 'NUM'), 'NOUN'],
#  [('618.1', 'NUM'), 'NOUN'],
#  [('77.6', 'NUM'), 'NOUN'],
#  [('earlier', 'ADJ'), 'ADV'],
#  [('12.52', 'NUM'), 'NOUN'],
#  [('11.95', 'NUM'), 'NOUN'],
#  [('next', 'ADJ'), 'ADP'],
#  [('Soviet', 'NOUN'), 'ADJ'],
#  [('off', 'ADP'), 'PRT'],
#  [('broadly', 'ADV'), 'NOUN'],
#  [('construed', 'VERB'), 'NOUN'],
#  [('emasculate', 'VERB'), 'NOUN'],
#  [('swallow', 'VERB'), 'NOUN'],
#  [('contrary', 'ADJ'), 'NOUN'],
#  [('the', 'NUM'), 'DET']]

# %% [markdown]
# Common Issues
# 1. Numners are tagged as Noun.
# 2. verb is tagged as noun.
# 3. *-226 are defined as noun
# 4. adjectives are defined as noun.
# 5. DET are tagged as ADP
# 6. alphabet-apphabet are tagged as Noun. It shuld be adjective

# %% [markdown]
# ### 2. Lexicon based taggers

# %% [markdown]
# We will create below rules for words and assign tags. And back plan will be most frequent tag

# %%
#regex pattern
patterns = [
    (r'.*ed$', 'VERB'),                          # past tense
    (r'.*es$', 'VERB'),                       # 3rd singular present
    (r'[^-]*ing$', 'VERB'),                         # 3rd singular present
    (r'.*ly$', 'ADV'),                           # Adverb ending with ly
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'),                # cardinal numbers
    (r'.[*T]?\*-[0-9]*$', 'X'),                         # other
    (r'\*-[0-9]*$', 'X'),                                 # other
    (r'\*-[0-9]*$', 'X'),                                 # other
    (r'[a-zA-Z]*-[a-zA-Z]*-?[a-zA-Z]*', 'ADJ'),            # adj
    (r'.*', 'NOUN')                                        # nouns
]

# %%
#Viterbi rule
def Viterbi_rule(words, patterns, train_bag = train_tagged_words):
    regexp_tagger = nltk.RegexpTagger(patterns)
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        if pmax==0:
            state.append(regexp_tagger.tag([word])[0][1])
        else:
            # getting state for which probability is maximum
            state_max = T[p.index(pmax)] 
            state.append(state_max)
    return list(zip(words, state))

# %%
# tagging the test sentences
start = time.time()
tagged_seq_rule = Viterbi_rule(test_words,patterns)
print("Time taken in seconds: ", time.time()-start)
# Out:
# Time taken in seconds:  674.0070085525513

# %%
# accuracy
check = [i for i, j in zip(tagged_seq_rule, test_tagged_words) if i == j] 
accuracy = len(check)/len(tagged_seq_rule)
accuracy_matrix['Lexicon Based'] = accuracy
accuracy
# Out:
# 0.9504971440660038

# %%
#To identify incorrect tagging by Viterbi  - rule based
incorrect_tags = [[j,i[1]] for i, j in zip(tagged_seq_rule, test_tagged_words) if i != j] 
incorrect_tags
# Out:
# [[('book', 'VERB'), 'NOUN'],
#  [('stocks', 'ADV'), 'NOUN'],
#  [('up', 'ADP'), 'PRT'],
#  [('over', 'PRT'), 'ADP'],
#  [('mine', 'ADJ'), 'NOUN'],
#  [('Palestinian', 'NOUN'), 'ADJ'],
#  [('first', 'ADV'), 'ADJ'],
#  [('Sit', 'VERB'), 'NOUN'],
#  [('down', 'ADV'), 'ADP'],
#  [('British', 'NOUN'), 'ADJ'],
#  [('halt', 'VERB'), 'NOUN'],
#  [('slides', 'VERB'), 'NOUN'],
#  [('most', 'ADV'), 'ADJ'],
#  [('athletic', 'ADJ'), 'NOUN'],
#  [('to', 'ADJ'), 'PRT'],
#  [('better', 'ADV'), 'ADJ'],
#  [('attempt', 'NOUN'), 'VERB'],
#  [('usurp', 'VERB'), 'NOUN'],
#  [('executive', 'ADJ'), 'NOUN'],
#  [('executive-office', 'NOUN'), 'ADJ'],
#  [('administer', 'VERB'), 'NOUN'],
#  [('applicable', 'ADJ'), 'NOUN'],
#  [('Louisiana-Pacific', 'NOUN'), 'ADJ'],
#  [('Five', 'NUM'), 'NOUN'],
#  [('Proper', 'ADJ'), 'NOUN'],
#  [('English', 'ADJ'), 'NOUN'],
#  [('highest-pitched', 'ADJ'), 'VERB'],
#  [('as', 'ADV'), 'ADP'],
#  [('62-year-old', 'ADJ'), 'NOUN'],
#  [('executive', 'ADJ'), 'NOUN'],
#  [('forest-product', 'NOUN'), 'ADJ'],
#  [('unsolicited', 'ADJ'), 'VERB'],
#  [('bid', 'NOUN'), 'VERB'],
#  [('that', 'DET'), 'ADP'],
#  [('diversified', 'VERB'), 'ADJ'],
#  [('that', 'DET'), 'ADP'],
#  [('impressive', 'ADJ'), 'NOUN'],
#  [('issue', 'VERB'), 'NOUN'],
#  [('29year', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('ECONOMIC', 'ADJ'), 'NOUN'],
#  [('APPEARS', 'VERB'), 'NOUN'],
#  [('off', 'ADP'), 'PRT'],
#  [('that', 'DET'), 'ADP'],
#  [('U.S.-Japanese', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('up', 'ADP'), 'ADV'],
#  [('past', 'NOUN'), 'ADJ'],
#  [('senior', 'NOUN'), 'ADJ'],
#  [('speculate', 'VERB'), 'NOUN'],
#  [('excess', 'NOUN'), 'ADJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('up', 'PRT'), 'ADV'],
#  [('smiles', 'NOUN'), 'VERB'],
#  [('rebound', 'NOUN'), 'VERB'],
#  [('Left', 'VERB'), 'NOUN'],
#  [('more', 'ADV'), 'ADJ'],
#  [('so', 'ADV'), 'ADP'],
#  [('much', 'ADV'), 'ADJ'],
#  [('preclinical', 'ADJ'), 'NOUN'],
#  [('vague', 'ADJ'), 'NOUN'],
#  [('mushy', 'ADJ'), 'NOUN'],
#  [('that', 'ADP'), 'DET'],
#  [('out', 'ADV'), 'PRT'],
#  [('le', 'DET'), 'NOUN'],
#  [('back', 'ADV'), 'PRT'],
#  [('care', 'NOUN'), 'VERB'],
#  [('care', 'NOUN'), 'VERB'],
#  [('clear', 'VERB'), 'ADJ'],
#  [('fuel', 'VERB'), 'NOUN'],
#  [('84-year-old', 'ADJ'), 'NOUN'],
#  [('individual', 'NOUN'), 'ADJ'],
#  [('intelligent', 'ADJ'), 'NOUN'],
#  [('insane', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('more', 'ADJ'), 'ADV'],
#  [('purhasing', 'NOUN'), 'VERB'],
#  [('report', 'NOUN'), 'VERB'],
#  [('movies', 'NOUN'), 'VERB'],
#  [('loose', 'ADJ'), 'NOUN'],
#  [('work', 'NOUN'), 'VERB'],
#  [('force', 'NOUN'), 'VERB'],
#  [('refer', 'VERB'), 'NOUN'],
#  [('clouding', 'NOUN'), 'VERB'],
#  [('about', 'ADV'), 'ADP'],
#  [('up', 'PRT'), 'ADV'],
#  [('solemn', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('intricate', 'ADJ'), 'NOUN'],
#  [('properties', 'NOUN'), 'VERB'],
#  [('Indexing', 'NOUN'), 'VERB'],
#  [('panic', 'VERB'), 'NOUN'],
#  [('so', 'ADP'), 'ADV'],
#  [('assistant', 'ADJ'), 'NOUN'],
#  [('following', 'VERB'), 'NOUN'],
#  [('dust-up', 'NOUN'), 'ADJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('shown', 'VERB'), 'NOUN'],
#  [('finest', 'ADJ'), 'NOUN'],
#  [('defeats', 'VERB'), 'NOUN'],
#  [('inkling', 'NOUN'), 'VERB'],
#  [('underprivileged', 'ADJ'), 'VERB'],
#  [('much', 'ADV'), 'ADJ'],
#  [('savvier', 'ADJ'), 'NOUN'],
#  [('much', 'ADJ'), 'ADV'],
#  [('as', 'ADV'), 'ADP'],
#  [('as', 'ADV'), 'ADP'],
#  [('Above', 'ADP'), 'NOUN'],
#  [('confused', 'VERB'), 'ADJ'],
#  [('around', 'PRT'), 'ADP'],
#  [('blinks', 'VERB'), 'NOUN'],
#  [('bar', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('abortion-related', 'ADJ'), 'VERB'],
#  [("'s", 'VERB'), 'PRT'],
#  [('more', 'ADV'), 'ADJ'],
#  [('further', 'ADV'), 'ADJ'],
#  [('load', 'VERB'), 'NOUN'],
#  [('up', 'PRT'), 'ADV'],
#  [('improbable', 'ADJ'), 'NOUN'],
#  [('help', 'NOUN'), 'VERB'],
#  [('plastic', 'NOUN'), 'ADJ'],
#  [('over', 'PRT'), 'ADP'],
#  [('seventh', 'ADJ'), 'NOUN'],
#  [("'82", 'NUM'), 'NOUN'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('closer', 'ADJ'), 'ADV'],
#  [('unwilling', 'ADJ'), 'VERB'],
#  [('investor-relations', 'NOUN'), 'ADJ'],
#  [('marketing-communications', 'NOUN'), 'ADJ'],
#  [('index-fund', 'ADJ'), 'NOUN'],
#  [('more', 'ADJ'), 'ADV'],
#  [('own', 'VERB'), 'ADJ'],
#  [('charge', 'VERB'), 'NOUN'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('matters', 'VERB'), 'NOUN'],
#  [('fine', 'ADV'), 'NOUN'],
#  [('chief', 'ADJ'), 'NOUN'],
#  [('father-in-law', 'NOUN'), 'ADJ'],
#  [('wealthy', 'ADJ'), 'NOUN'],
#  [('well-connected', 'ADJ'), 'VERB'],
#  [('financing', 'NOUN'), 'VERB'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('that', 'DET'), 'ADP'],
#  [('cavernous', 'ADJ'), 'NOUN'],
#  [('benefits', 'VERB'), 'NOUN'],
#  [('U.S.', 'ADJ'), 'NOUN'],
#  [('close', 'NOUN'), 'VERB'],
#  [('appeal', 'VERB'), 'NOUN'],
#  [('burn', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('select', 'VERB'), 'NOUN'],
#  [('net', 'NOUN'), 'ADJ'],
#  [('unrestricted', 'ADJ'), 'VERB'],
#  [('that', 'DET'), 'ADP'],
#  [('firm', 'ADJ'), 'NOUN'],
#  [('opening', 'NOUN'), 'VERB'],
#  [('less', 'ADJ'), 'ADV'],
#  [('higher', 'ADV'), 'ADJ'],
#  [('trading', 'VERB'), 'NOUN'],
#  [('1980s', 'NOUN'), 'NUM'],
#  [('yellow', 'ADJ'), 'NOUN'],
#  [('record', 'ADJ'), 'NOUN'],
#  [('Four', 'NUM'), 'NOUN'],
#  [('half', 'NOUN'), 'DET'],
#  [('27-year', 'ADJ'), 'NOUN'],
#  [('information-services', 'NOUN'), 'VERB'],
#  [('Southeast', 'ADJ'), 'NOUN'],
#  [('uses', 'NOUN'), 'VERB'],
#  [('post', 'NOUN'), 'VERB'],
#  [('little', 'ADV'), 'ADJ'],
#  [('more', 'ADV'), 'ADJ'],
#  [('what', 'DET'), 'PRON'],
#  [('that', 'DET'), 'ADP'],
#  [('that', 'DET'), 'ADP'],
#  [('uptick', 'VERB'), 'NOUN'],
#  [('head', 'ADJ'), 'NOUN'],
#  [('insurance-company', 'NOUN'), 'ADJ'],
#  [('comments', 'VERB'), 'NOUN'],
#  [('increases', 'VERB'), 'NOUN'],
#  [('63-year-old', 'ADJ'), 'NOUN'],
#  [('English', 'NOUN'), 'ADJ'],
#  [('CoreStates', 'NOUN'), 'VERB'],
#  [('account', 'NOUN'), 'VERB'],
#  [('there', 'ADV'), 'DET'],
#  [('what', 'DET'), 'PRON'],
#  [('open', 'ADJ'), 'VERB'],
#  [('drink', 'NOUN'), 'VERB'],
#  [('up', 'ADP'), 'ADV'],
#  [('cardiovascular', 'ADJ'), 'NOUN'],
#  [('infectious', 'ADJ'), 'NOUN'],
#  [('guarantee', 'NOUN'), 'VERB'],
#  [('operating', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('half', 'NOUN'), 'DET'],
#  [('espouse', 'VERB'), 'NOUN'],
#  [('about', 'ADV'), 'ADP'],
#  [('one-third', 'ADJ'), 'NOUN'],
#  [('finance', 'NOUN'), 'VERB'],
#  [('59-year-old', 'ADJ'), 'NOUN'],
#  [('heebie-jeebies', 'NOUN'), 'VERB'],
#  [('much', 'ADJ'), 'ADV'],
#  [('point', 'NOUN'), 'VERB'],
#  [('audit', 'NOUN'), 'VERB'],
#  [('stand', 'NOUN'), 'VERB'],
#  [('display', 'VERB'), 'NOUN'],
#  [('underline', 'VERB'), 'NOUN'],
#  [('Old-House', 'NOUN'), 'ADJ'],
#  [('publishing', 'NOUN'), 'VERB'],
#  [('all', 'ADV'), 'DET'],
#  [('following', 'NOUN'), 'VERB'],
#  [('240-page', 'ADJ'), 'NOUN'],
#  [('Iran-Contra', 'NOUN'), 'ADJ'],
#  [('Next', 'ADJ'), 'NOUN'],
#  [('launch', 'NOUN'), 'VERB'],
#  [('capped', 'VERB'), 'ADJ'],
#  [('Philippine', 'ADJ'), 'NOUN'],
#  [('the', 'NOUN'), 'DET'],
#  [('Spending', 'NOUN'), 'VERB'],
#  [('nonresidential', 'ADJ'), 'NOUN'],
#  [('off', 'ADJ'), 'PRT'],
#  [('awaits', 'VERB'), 'NOUN'],
#  [('point', 'VERB'), 'NOUN'],
#  [('B-1B', 'NOUN'), 'ADJ'],
#  [('out', 'ADP'), 'PRT'],
#  [('half', 'DET'), 'NOUN'],
#  [('earlier', 'ADJ'), 'ADV'],
#  [('next', 'ADJ'), 'ADP'],
#  [('Soviet', 'NOUN'), 'ADJ'],
#  [('off', 'ADP'), 'PRT'],
#  [('emasculate', 'VERB'), 'NOUN'],
#  [('swallow', 'VERB'), 'NOUN'],
#  [('contrary', 'ADJ'), 'NOUN'],
#  [('the', 'NUM'), 'DET']]

# %% [markdown]
# Common issues
# 1. 1st form of verb is tagged as noun.
# 2. nouns ending with ed are tagged as verb.

# %% [markdown]
# ### 3. Ignoring zero state probability for unknown words

# %%
#Viterbi -  ignore zero
def Viterbi_ignorezero(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            if emission_p ==0:emission_p=sys.float_info.epsilon
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluate State probability ignoring

# %%
# tagging the test sentences
start = time.time()
tagged_seq_ignorezero = Viterbi_ignorezero(test_words)
print("Time taken in seconds: ", time.time()-start)
# Out:
# Time taken in seconds:  702.0532686710358

# %%
# accuracy
check = [i for i, j in zip(tagged_seq_ignorezero, test_tagged_words) if i == j] 
accuracy = len(check)/len(tagged_seq_ignorezero)
accuracy_matrix['Viterbi - Ignore state probability for unknown words'] = accuracy
accuracy
# Out:
# 0.9331499894224666

# %%
#To identify incorrect tagging by Viterbi  - ignore zero state probability algo
incorrect_tags = [[j,i[1]] for i, j in zip(tagged_seq_ignorezero, test_tagged_words) if i != j] 
incorrect_tags
# Out:
# [[('book', 'VERB'), 'NOUN'],
#  [('stocks', 'ADV'), 'NOUN'],
#  [('up', 'ADP'), 'PRT'],
#  [('over', 'PRT'), 'ADP'],
#  [('mine', 'ADJ'), 'NOUN'],
#  [('Palestinian', 'NOUN'), 'ADJ'],
#  [('first', 'ADV'), 'ADJ'],
#  [('clamped', 'VERB'), 'X'],
#  [('ankle', 'NOUN'), 'VERB'],
#  [('third-largest', 'ADJ'), 'NOUN'],
#  [('fifth-largest', 'ADJ'), 'NOUN'],
#  [('89.7', 'NUM'), 'NOUN'],
#  [('141.9', 'NUM'), 'NOUN'],
#  [('94.8', 'NUM'), 'NOUN'],
#  [('149.9', 'NUM'), 'NOUN'],
#  [('British', 'NOUN'), 'ADJ'],
#  [('halt', 'VERB'), 'NOUN'],
#  [('slides', 'VERB'), 'NOUN'],
#  [('most', 'ADV'), 'ADJ'],
#  [('athletic', 'ADJ'), 'DET'],
#  [('to', 'ADJ'), 'PRT'],
#  [('better', 'ADV'), 'ADJ'],
#  [('attempt', 'NOUN'), 'VERB'],
#  [('609', 'NUM'), 'NOUN'],
#  [('administer', 'VERB'), 'NOUN'],
#  [('disapproved', 'VERB'), 'X'],
#  [('*-58', 'X'), 'VERB'],
#  [('disapproval', 'NOUN'), 'DET'],
#  [('accordance', 'NOUN'), 'DET'],
#  [('applicable', 'ADJ'), 'NOUN'],
#  [('Five', 'NUM'), 'NOUN'],
#  [('Proper', 'ADJ'), 'NOUN'],
#  [('English', 'ADJ'), 'NOUN'],
#  [('highest-pitched', 'ADJ'), 'NOUN'],
#  [('descending', 'VERB'), 'NOUN'],
#  [('as', 'ADV'), 'ADP'],
#  [('62-year-old', 'ADJ'), 'NOUN'],
#  [('executive', 'ADJ'), 'NOUN'],
#  [('unsolicited', 'ADJ'), 'VERB'],
#  [('3.19', 'NUM'), 'NOUN'],
#  [('bid', 'NOUN'), 'VERB'],
#  [('that', 'DET'), 'ADP'],
#  [('diversified', 'VERB'), 'ADJ'],
#  [('that', 'DET'), 'ADP'],
#  [('impressive', 'ADJ'), 'DET'],
#  [('issue', 'VERB'), 'NOUN'],
#  [('29year', 'ADJ'), 'DET'],
#  [('nine-month', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('ECONOMIC', 'ADJ'), 'NOUN'],
#  [('APPEARS', 'VERB'), 'NOUN'],
#  [('off', 'ADP'), 'PRT'],
#  [('that', 'DET'), 'ADP'],
#  [('U.S.-Japanese', 'ADJ'), 'NOUN'],
#  [('*T*-174', 'X'), 'NOUN'],
#  [('hotels', 'NOUN'), 'X'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-175', 'X'), 'DET'],
#  [('masters', 'NOUN'), 'DET'],
#  [('up', 'ADP'), 'ADV'],
#  [('past', 'NOUN'), 'ADJ'],
#  [('Kelli', 'NOUN'), 'VERB'],
#  [('Green', 'NOUN'), 'X'],
#  [('senior', 'NOUN'), 'ADJ'],
#  [('yen-support', 'ADJ'), 'NOUN'],
#  [('150.00', 'NUM'), 'NOUN'],
#  [('excess', 'NOUN'), 'ADJ'],
#  [('about', 'ADV'), 'ADP'],
#  [('up', 'PRT'), 'ADV'],
#  [('rebound', 'NOUN'), 'VERB'],
#  [('pushes', 'VERB'), 'X'],
#  [('more', 'ADV'), 'ADJ'],
#  [('so', 'ADV'), 'ADP'],
#  [('much', 'ADV'), 'ADJ'],
#  [('preclinical', 'ADJ'), 'X'],
#  [('vague', 'ADJ'), 'NOUN'],
#  [('mushy', 'ADJ'), 'NOUN'],
#  [('that', 'ADP'), 'DET'],
#  [('out', 'ADV'), 'PRT'],
#  [('le', 'DET'), 'NOUN'],
#  [('115', 'NUM'), 'NOUN'],
#  [('back', 'ADV'), 'PRT'],
#  [('foldability', 'NOUN'), 'VERB'],
#  [('inserted', 'VERB'), 'X'],
#  [('care', 'NOUN'), 'VERB'],
#  [('care', 'NOUN'), 'VERB'],
#  [('clear', 'VERB'), 'ADJ'],
#  [('fuel', 'VERB'), 'NOUN'],
#  [('84-year-old', 'ADJ'), 'NOUN'],
#  [('amazingly', 'ADV'), 'X'],
#  [('sight', 'NOUN'), 'DET'],
#  [('*T*-178', 'X'), 'NOUN'],
#  [('692', 'NUM'), 'VERB'],
#  [('960', 'NUM'), 'VERB'],
#  [('individual', 'NOUN'), 'ADJ'],
#  [('51.6', 'NUM'), 'VERB'],
#  [('readings', 'NOUN'), 'DET'],
#  [('wrestling', 'VERB'), 'X'],
#  [('intelligent', 'ADJ'), 'VERB'],
#  [('insane', 'ADJ'), 'VERB'],
#  [('that', 'DET'), 'ADP'],
#  [('tailor-made', 'ADJ'), 'X'],
#  [('more', 'ADJ'), 'ADV'],
#  [('report', 'NOUN'), 'VERB'],
#  [('marvelously', 'ADV'), 'NOUN'],
#  [('loose', 'ADJ'), 'NOUN'],
#  [('work', 'NOUN'), 'VERB'],
#  [('force', 'NOUN'), 'VERB'],
#  [('refer', 'VERB'), 'NOUN'],
#  [('about', 'ADV'), 'ADP'],
#  [('maturing', 'VERB'), 'DET'],
#  [('up', 'PRT'), 'ADV'],
#  [('filled', 'VERB'), 'NOUN'],
#  [('solemn', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-226', 'X'), 'DET'],
#  [('intricate', 'ADJ'), 'DET'],
#  [('faultlessly', 'ADV'), 'NOUN'],
#  [('panic', 'VERB'), 'NOUN'],
#  [('so', 'ADP'), 'ADV'],
#  [('crying', 'VERB'), 'NOUN'],
#  [('assistant', 'ADJ'), 'NOUN'],
#  [('Ilminster', 'NOUN'), 'DET'],
#  [('following', 'VERB'), 'NOUN'],
#  [('about', 'ADV'), 'ADP'],
#  [('8.75', 'NUM'), 'VERB'],
#  [('shown', 'VERB'), 'X'],
#  [('finest', 'ADJ'), 'VERB'],
#  [('472', 'NUM'), 'NOUN'],
#  [('underprivileged', 'ADJ'), 'NOUN'],
#  [('*T*-96', 'X'), 'VERB'],
#  [('alumni', 'NOUN'), 'VERB'],
#  [('cultivated', 'VERB'), 'X'],
#  [('much', 'ADV'), 'ADJ'],
#  [('savvier', 'ADJ'), 'NOUN'],
#  [('much', 'ADJ'), 'ADV'],
#  [('burned', 'VERB'), 'X'],
#  [('wrath', 'NOUN'), 'VERB'],
#  [('Bolivia', 'NOUN'), 'X'],
#  [('as', 'ADV'), 'ADP'],
#  [('delayed', 'VERB'), 'X'],
#  [('as', 'ADV'), 'ADP'],
#  [('Above', 'ADP'), 'NOUN'],
#  [('confused', 'VERB'), 'ADJ'],
#  [('around', 'PRT'), 'ADP'],
#  [('blinks', 'VERB'), 'NOUN'],
#  [('bar', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('abortion-related', 'ADJ'), 'X'],
#  [("'s", 'VERB'), 'PRT'],
#  [('more', 'ADV'), 'ADJ'],
#  [('further', 'ADV'), 'ADJ'],
#  [('load', 'VERB'), 'NOUN'],
#  [('dreamed', 'VERB'), 'NOUN'],
#  [('improbable', 'ADJ'), 'VERB'],
#  [('shop', 'NOUN'), 'VERB'],
#  [('high-rise', 'ADJ'), 'NOUN'],
#  [('help', 'NOUN'), 'VERB'],
#  [('arrows', 'NOUN'), 'DET'],
#  [('polystyrene', 'NOUN'), 'VERB'],
#  [('foam', 'NOUN'), 'X'],
#  [('plastic', 'NOUN'), 'ADJ'],
#  [('non-biodegradable', 'ADJ'), 'X'],
#  [('over', 'PRT'), 'ADP'],
#  [('seventh', 'ADJ'), 'VERB'],
#  [('principal', 'NOUN'), 'ADJ'],
#  [("'82", 'NUM'), 'NOUN'],
#  [('115', 'NUM'), 'NOUN'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('closer', 'ADJ'), 'ADV'],
#  [('unwilling', 'ADJ'), 'VERB'],
#  [('Braun', 'NOUN'), 'X'],
#  [('headed', 'VERB'), 'NOUN'],
#  [('index-fund', 'ADJ'), 'NOUN'],
#  [('more', 'ADJ'), 'ADV'],
#  [('own', 'VERB'), 'ADJ'],
#  [('flirted', 'VERB'), 'X'],
#  [('charge', 'VERB'), 'NOUN'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('matters', 'VERB'), 'NOUN'],
#  [('fine', 'ADV'), 'NOUN'],
#  [('chief', 'ADJ'), 'NOUN'],
#  [('father-in-law', 'NOUN'), 'VERB'],
#  [('wealthy', 'ADJ'), 'NOUN'],
#  [('well-connected', 'ADJ'), 'NOUN'],
#  [('financing', 'NOUN'), 'VERB'],
#  [('American', 'NOUN'), 'ADJ'],
#  [('Moon', 'NOUN'), 'VERB'],
#  [('Landrieu', 'NOUN'), 'X'],
#  [('that', 'DET'), 'ADP'],
#  [('cavernous', 'ADJ'), 'VERB'],
#  [('money-losing', 'ADJ'), 'NOUN'],
#  [('benefits', 'VERB'), 'NOUN'],
#  [('U.S.', 'ADJ'), 'NOUN'],
#  [('143.93', 'NUM'), 'DET'],
#  [('close', 'NOUN'), 'VERB'],
#  [('143.08', 'NUM'), 'DET'],
#  [('appeal', 'VERB'), 'NOUN'],
#  [('burn', 'VERB'), 'NOUN'],
#  [('cleaner-burning', 'ADJ'), 'NOUN'],
#  [('858,000', 'NUM'), 'DET'],
#  [('overvalued', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('net', 'NOUN'), 'ADJ'],
#  [('306', 'NUM'), 'NOUN'],
#  [('unrestricted', 'ADJ'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('firm', 'ADJ'), 'NOUN'],
#  [('opening', 'NOUN'), 'VERB'],
#  [('less', 'ADJ'), 'ADV'],
#  [('higher', 'ADV'), 'ADJ'],
#  [('trading', 'VERB'), 'NOUN'],
#  [('1980s', 'NOUN'), 'NUM'],
#  [('glory', 'NOUN'), 'VERB'],
#  [('faded', 'VERB'), 'X'],
#  [('yellow', 'ADJ'), 'NOUN'],
#  [('record', 'ADJ'), 'NOUN'],
#  [('550,000', 'NUM'), 'NOUN'],
#  [('Four', 'NUM'), 'NOUN'],
#  [('half', 'NOUN'), 'DET'],
#  [('27-year', 'ADJ'), 'NOUN'],
#  [('Southeast', 'ADJ'), 'NOUN'],
#  [('1997', 'NUM'), 'DET'],
#  [('uses', 'NOUN'), 'VERB'],
#  [('cancer-causing', 'ADJ'), 'DET'],
#  [('outlawed', 'VERB'), 'X'],
#  [('stemmed', 'VERB'), 'NOUN'],
#  [('post', 'NOUN'), 'VERB'],
#  [('little', 'ADV'), 'ADJ'],
#  [('more', 'ADV'), 'ADJ'],
#  [('what', 'DET'), 'PRON'],
#  [('that', 'DET'), 'ADP'],
#  [('that', 'DET'), 'ADP'],
#  [('*T*-117', 'X'), 'DET'],
#  [('uptick', 'VERB'), 'NOUN'],
#  [('head', 'ADJ'), 'NOUN'],
#  [('comments', 'VERB'), 'NOUN'],
#  [('increases', 'VERB'), 'NOUN'],
#  [('jeopardy', 'NOUN'), 'DET'],
#  [('14.75', 'NUM'), 'NOUN'],
#  [('63-year-old', 'ADJ'), 'NOUN'],
#  [('English', 'NOUN'), 'ADJ'],
#  [('Earle', 'NOUN'), 'X'],
#  [('Palmer', 'NOUN'), 'VERB'],
#  [('account', 'NOUN'), 'VERB'],
#  [('there', 'ADV'), 'DET'],
#  [('what', 'DET'), 'PRON'],
#  [('escape', 'NOUN'), 'DET'],
#  [('open', 'ADJ'), 'VERB'],
#  [('drink', 'NOUN'), 'VERB'],
#  [('up', 'ADP'), 'ADV'],
#  [('malnutrition', 'NOUN'), 'DET'],
#  [('cardiovascular', 'ADJ'), 'NOUN'],
#  [('infectious', 'ADJ'), 'NOUN'],
#  [('assaults', 'NOUN'), 'DET'],
#  [('*T*-91', 'X'), 'VERB'],
#  [('879', 'NUM'), 'DET'],
#  [('13.90', 'NUM'), 'NOUN'],
#  [('guarantee', 'NOUN'), 'VERB'],
#  [('operating', 'VERB'), 'NOUN'],
#  [('shopped', 'VERB'), 'NOUN'],
#  [('that', 'DET'), 'ADP'],
#  [('half', 'NOUN'), 'DET'],
#  [('espouse', 'VERB'), 'NOUN'],
#  [('about', 'ADV'), 'ADP'],
#  [('one-third', 'ADJ'), 'NOUN'],
#  [('finance', 'NOUN'), 'VERB'],
#  [('deteriorating', 'VERB'), 'DET'],
#  [('59-year-old', 'ADJ'), 'NOUN'],
#  [('much', 'ADJ'), 'ADV'],
#  [('point', 'NOUN'), 'VERB'],
#  [('audit', 'NOUN'), 'VERB'],
#  [('stand', 'NOUN'), 'VERB'],
#  [('underline', 'VERB'), 'NOUN'],
#  [('publishing', 'NOUN'), 'VERB'],
#  [('126,000', 'NUM'), 'NOUN'],
#  [('all', 'ADV'), 'DET'],
#  [('following', 'NOUN'), 'VERB'],
#  [('round-trip', 'ADJ'), 'NOUN'],
#  [('Trans', 'NOUN'), 'DET'],
#  [('soaring', 'VERB'), 'NOUN'],
#  [('reclaimed', 'VERB'), 'NOUN'],
#  [('240-page', 'ADJ'), 'VERB'],
#  [('report', 'NOUN'), 'VERB'],
#  [('221.4', 'NUM'), 'NOUN'],
#  [('Next', 'ADJ'), 'NOUN'],
#  [('launch', 'NOUN'), 'VERB'],
#  [('capped', 'VERB'), 'ADJ'],
#  [('Philippine', 'ADJ'), 'DET'],
#  [('the', 'NOUN'), 'DET'],
#  [('midyear', 'NOUN'), 'DET'],
#  [('nonresidential', 'ADJ'), 'NOUN'],
#  [('off', 'ADJ'), 'PRT'],
#  [('99.1', 'NUM'), 'NOUN'],
#  [('awaits', 'VERB'), 'NOUN'],
#  [('point', 'VERB'), 'NOUN'],
#  [('sagged', 'VERB'), 'NOUN'],
#  [('B-1B', 'NOUN'), 'ADJ'],
#  [('out', 'ADP'), 'PRT'],
#  [('half', 'DET'), 'NOUN'],
#  [('88.32', 'NUM'), 'VERB'],
#  [('618.1', 'NUM'), 'NOUN'],
#  [('77.6', 'NUM'), 'DET'],
#  [('earlier', 'ADJ'), 'ADV'],
#  [('12.52', 'NUM'), 'NOUN'],
#  [('11.95', 'NUM'), 'NOUN'],
#  [('next', 'ADJ'), 'ADP'],
#  [('Soviet', 'NOUN'), 'ADJ'],
#  [('off', 'ADP'), 'PRT'],
#  [('Malta', 'NOUN'), 'VERB'],
#  [('broadly', 'ADV'), 'VERB'],
#  [('construed', 'VERB'), 'X'],
#  [('emasculate', 'VERB'), 'X'],
#  [('swallow', 'VERB'), 'NOUN'],
#  [('contrary', 'ADJ'), 'NOUN'],
#  [('the', 'NUM'), 'DET']]

# %% [markdown]
# Common issues:
# 1. verb is defined as noun.
# 2. num is defined as noun.
# 3. other words are incorrectly assigned to any randon tag.
# 4. Adj are defined as noun.
# 5. words joined by (-) are incorrectly assigned

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
#Accuracy matrix
accuracy_matrix
# Out:
# {'Vanilla': 0.9033213454622382,
#  'Most Frequent POS': 0.9348423947535435,
#  'Lexicon Based': 0.9504971440660038,
#  'Viterbi - Ignore state probability for unknown words': 0.9331499894224666}

# %% [markdown]
# ##### Lexicon Based is giving the highest probability

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
#Words incorrectly tagged by Vanilla but corrected by Regex based tagger.
fixed_rule_corrected = [[i[0],i[1],j[1],k[1]] for i, j,k in zip(test_tagged_words,tagged_seq,tagged_seq_rule) if i != j and i==k]
fixed_rule_corrected = pd.DataFrame(fixed_rule_corrected,columns=['word','correct_pos','vanilla_pos','rule_pos'])
fixed_rule_corrected
# Out:
#             word correct_pos vanilla_pos rule_pos
# 0        ignored        VERB        CONJ     VERB
# 1        Preston        NOUN        CONJ     NOUN
# 2     Birmingham        NOUN        CONJ     NOUN
# 3            Ala        NOUN        CONJ     NOUN
# 4        clamped        VERB        CONJ     VERB
# ..           ...         ...         ...      ...
# 224         NCNB        NOUN        CONJ     NOUN
# 225  Connections        NOUN        CONJ     NOUN
# 226       adults        NOUN        CONJ     NOUN
# 227      broadly         ADV        CONJ      ADV
# 228    construed        VERB        CONJ     VERB
#
# [229 rows x 4 columns]

# %%
#Analysis
fixed_rule_corrected['vanilla_pos'].value_counts()
# Out:
# CONJ    225
# VERB      2
# DET       1
# ADJ       1
# Name: vanilla_pos, dtype: int64

# %%
#Words incorrectly tagged by Vanilla but corrected by Most frequent tagger.
frequent_corrected = [[i[0],i[1],j[1],k[1]] for i, j,k in zip(test_tagged_words,tagged_seq,tagged_seq_frequent) if i != j and i==k]
frequent_corrected = pd.DataFrame(frequent_corrected,columns=['word','correct_pos','vanilla_pos','frequent_pos'])
frequent_corrected
# Out:
#             word correct_pos vanilla_pos frequent_pos
# 0        Preston        NOUN        CONJ         NOUN
# 1     Birmingham        NOUN        CONJ         NOUN
# 2            Ala        NOUN        CONJ         NOUN
# 3          ankle        NOUN        CONJ         NOUN
# 4             Z.        NOUN        CONJ         NOUN
# ..           ...         ...         ...          ...
# 151    shipboard        NOUN        CONJ         NOUN
# 152        Malta        NOUN        CONJ         NOUN
# 153         NCNB        NOUN        CONJ         NOUN
# 154  Connections        NOUN        CONJ         NOUN
# 155       adults        NOUN        CONJ         NOUN
#
# [156 rows x 4 columns]

# %%
#Analysis
frequent_corrected['vanilla_pos'].value_counts()
# Out:
# CONJ    151
# VERB      2
# ADV       1
# DET       1
# ADJ       1
# Name: vanilla_pos, dtype: int64

# %%
#Words incorrectly tagged by Vanilla but corrected by Viterbi - ignore zero state probability
zero_state_corrected = [[i[0],i[1],j[1],k[1]] for i, j,k in zip(test_tagged_words,tagged_seq,tagged_seq_ignorezero) if i != j and i==k]
zero_state_corrected = pd.DataFrame(zero_state_corrected,columns=['word','correct_pos','vanilla_pos','zero_state_pos'])
zero_state_corrected
# Out:
#             word correct_pos vanilla_pos zero_state_pos
# 0        ignored        VERB        CONJ           VERB
# 1        Preston        NOUN        CONJ           NOUN
# 2     Birmingham        NOUN        CONJ           NOUN
# 3            Ala        NOUN        CONJ           NOUN
# 4             Z.        NOUN        CONJ           NOUN
# ..           ...         ...         ...            ...
# 142      bombers        NOUN        CONJ           NOUN
# 143    shipboard        NOUN        CONJ           NOUN
# 144         NCNB        NOUN        CONJ           NOUN
# 145  Connections        NOUN        CONJ           NOUN
# 146       adults        NOUN        CONJ           NOUN
#
# [147 rows x 4 columns]

# %%
#Analysis
zero_state_corrected['vanilla_pos'].value_counts()
# Out:
# CONJ    142
# VERB      2
# ADV       1
# DET       1
# ADJ       1
# Name: vanilla_pos, dtype: int64

# %% [markdown]
# 1. In Vanilla -  Most common issue was -  Most tags were in-correctly assigned as Determinent. After analysis, we found thay viterbi algo is assigining all unknown words are determinent. (accuracy 90 percent)
# 2. Later we used, most frequent tagger (Noun) -  It removed the problem of Determinent and increased the accuract to 93 percent. But now, most is-correct POS tagging was Noun.
# 3. We further analyzed the problem and created the rules to correctly identify verbs, adverb, number, etc. After the accuracy increased to --- 95 %
#
# 4. Later, we tried one more approch by ignoring state probability of unknown words. The accuracy is about 93 percent. And problem remain the same. i.e - Most words are incorrectly assigned as noun. But, the issue of inccorrent words tagged as DET is resolved.
